# %% [markdown]
# # Merging Work Tasks to General Work Activities
#
# The purpose of this notebook is to merge the original O\*NET data into one comprehesive CSV that will contain work tasks and their associated general work activities (GWA). The work tasks will be the input data into a machine learning model used to predict GWA, which act as labels.
#
# **Last Updated**: Wednesday July 24, 2019
# <br> **Author**: Rebecca Hu
#
# <i> Note</i>: All original O\*NET data text files should be located in a folder labeled "original_onet_data". If that folder is no longer available, the data can be re-downloaded [here](https://www.onetcenter.org/database.html#act) (click the <i> Individual Files </i> Tab, then look under <i>Work Activities</i>). The files used include <i>DWA Reference.txt</i>, <i>Task Statements.txt</i>, <i>Tasks to DWAs.txt</i>, and <i>Work Activities.txt</i>.

# %%
# import necessary packages
import pandas as pd
import numpy as np
import re

# %% [markdown]
# Let's take a look at each of the files we grabbed from the O\*NET website. We're looking for a way to merge tasks with their associated GWA.

# %%
tasks = pd.read_csv('original_onet_data/Task Statements.txt', sep = '\t')

# %%
print(tasks.shape[0], 'rows')
tasks.head()
# Out:
# 19636 rows
#   O*NET-SOC Code  Task ID                                               Task  \
# 0     11-1011.00     8823  Direct or coordinate an organization's financi...
# 1     11-1011.00     8831  Appoint department heads or managers and assig...
# 2     11-1011.00     8825  Analyze operations to evaluate performance of ...
# 3     11-1011.00     8826  Direct, plan, or implement policies, objective...
# 4     11-1011.00     8827  Prepare budgets for approval, including those ...
#
#   Task Type  Incumbents Responding     Date Domain Source
# 0      Core                   87.0  07/2014     Incumbent
# 1      Core                   87.0  07/2014     Incumbent
# 2      Core                   87.0  07/2014     Incumbent
# 3      Core                   87.0  07/2014     Incumbent
# 4      Core                   87.0  07/2014     Incumbent

# %% [markdown]
# <i>Task Statements.txt</i> contains the text of each individual task which we will definitely need, as well as the tasks' associated SOC Codes and Task IDs which could be useful for merging multiple pd.DataFrame objects together. Notice that the SOC codes are not unique to the tasks, but the Task IDs are.

# %%
task_to_dwa = pd.read_csv('original_onet_data/Tasks to DWAs.txt', sep = '\t')

# %%
print(task_to_dwa.shape[0], 'rows')
task_to_dwa.head()
# Out:
# 22936 rows
#   O*NET-SOC Code  Task ID             DWA ID     Date Domain Source
# 0     11-1011.00    20461  4.A.2.a.4.I09.D03  07/2014       Analyst
# 1     11-1011.00    20461  4.A.4.b.6.I08.D04  07/2014       Analyst
# 2     11-1011.00     8823  4.A.4.b.4.I09.D02  03/2014       Analyst
# 3     11-1011.00     8824  4.A.4.a.2.I03.D14  03/2014       Analyst
# 4     11-1011.00     8825  4.A.2.a.4.I07.D09  03/2014       Analyst

# %% [markdown]
# <i>Tasks to DWAs.txt</i> also contains SOC Codes and Task IDs, but it also contains information about the Detailed Work Activity (DWA) associated with each task. We don't necessarily need any information about a task's DWA, but it could be useful for intermediate merging. Notice that in this table, Task IDs are not unique, so one task could have multiple DWAs associated with it.

# %%
gwa = pd.read_csv('original_onet_data/Work Activities.txt', sep = '\t')

# %%
print(gwa.shape[0], 'rows')
gwa.head()
# Out:
# 79294 rows
#   O*NET-SOC Code Element ID                                   Element Name  \
# 0     11-1011.00  4.A.1.a.1                            Getting Information
# 1     11-1011.00  4.A.1.a.1                            Getting Information
# 2     11-1011.00  4.A.1.a.2  Monitor Processes, Materials, or Surroundings
# 3     11-1011.00  4.A.1.a.2  Monitor Processes, Materials, or Surroundings
# 4     11-1011.00  4.A.1.b.1       Identifying Objects, Actions, and Events
#
#   Scale ID  Data Value     N  Standard Error  Lower CI Bound  Upper CI Bound  \
# 0       IM        4.72  35.0            0.13            4.46            4.98
# 1       LV        5.35  35.0            0.23            4.89            5.81
# 2       IM        3.68  35.0            0.17            3.33            4.03
# 3       LV        4.76  34.0            0.27            4.22            5.30
# 4       IM        4.20  35.0            0.15            3.91            4.50
#
#   Recommend Suppress Not Relevant     Date Domain Source
# 0                  N          NaN  07/2014     Incumbent
# 1                  N            N  07/2014     Incumbent
# 2                  N          NaN  07/2014     Incumbent
# 3                  N            N  07/2014     Incumbent
# 4                  N          NaN  07/2014     Incumbent

# %% [markdown]
# <i>Work Activities.txt</i> contains the GWA we need to label the Task information with under the column header "Element Name". Each GWA is also associated with a unique ID under "Element ID". We should be able to use these IDs to merge the GWAs with the Tasks. (Also, it is unclear what each row in this file represents (?) but we can still utilize the information in provides on GWAs for our purposes)

# %%
dwa = pd.read_csv('original_onet_data/DWA Reference.txt', sep = '\t')

# %%
print(dwa.shape[0], 'rows')
dwa.head()
# Out:
# 2070 rows
#   Element ID         IWA ID             DWA ID  \
# 0  4.A.1.a.1  4.A.1.a.1.I01  4.A.1.a.1.I01.D01
# 1  4.A.1.a.1  4.A.1.a.1.I01  4.A.1.a.1.I01.D02
# 2  4.A.1.a.1  4.A.1.a.1.I01  4.A.1.a.1.I01.D03
# 3  4.A.1.a.1  4.A.1.a.1.I01  4.A.1.a.1.I01.D04
# 4  4.A.1.a.1  4.A.1.a.1.I02  4.A.1.a.1.I02.D01
#
#                                            DWA Title
# 0                    Review art or design materials.
# 1             Study details of musical compositions.
# 2  Review production information to determine cos...
# 3   Study scripts to determine project requirements.
# 4        Read materials to determine needed actions.

# %% [markdown]
# <i>DWA Reference.txt</i> maps each DWA to its associated GWA ID (In this data, GWA are referred to as Elements). Notice that the data under the column headers "Element ID", "IWA ID", and "DWA ID" are all related. The DWA ID numbers are extensions of the IWA ID which are extensions of the Element ID (or GWA ID).
#
# ---
#
# Now that we have an idea of the data we have, we can determine how to best isolate the data we're interested in using. We know we have to start with the pd.DataFrame, <i>tasks</i>, because it is the only object that contains the text of each indivdual work task. Then, we know that we'll need to combine the work tasks in the <i>tasks</i> object to the <i>gwa</i> pd.DataFrame in some way, as <i>gwa</i> is the only object with information about the GWAs. We can use the <i>dwa</i> and <i>task_to_dwa</i> pd.DataFrames as intermediaries to help us link together the <i>tasks</i> and <i>gwa</i> pd.DataFrames.
#
# <b>Strategy</b>: Merge the <i>tasks</i> and <i>task_to_dwa</i> pd.DataFrames together using the column "Task ID". Then, we'll have the DWA ID associated with each task. We previously noticed that the GWA ID can be derrived from the IWA and DWA IDs, so now we have a way to combine the information for the tasks with their GWA IDs. Lastly, we can use the GWA IDs to connect the tasks to the text of the GWAs using the <i>gwa</i> object. (Note: We ended up not needing the <i>dwa</i> pd.DataFrame. Also, we could have saved a few steps by just connecting the Task IDs with their GWA IDs, but using the human-readable text for the tasks and GWAs will make it easier for us to conduct prelimanary exploratory data analysis later)

# %%
#create dictionary of {gwa id: gwa descriptions}
gwa_dict = pd.Series(gwa['Element Name'].values, index=gwa['Element ID']).to_dict()
print(len(gwa_dict))
gwa_dict
# Out:
# 41
# {'4.A.1.a.1': 'Getting Information',
#  '4.A.1.a.2': 'Monitor Processes, Materials, or Surroundings',
#  '4.A.1.b.1': 'Identifying Objects, Actions, and Events',
#  '4.A.1.b.2': 'Inspecting Equipment, Structures, or Material',
#  '4.A.1.b.3': 'Estimating the Quantifiable Characteristics of Products, Events, or Information',
#  '4.A.2.a.1': 'Judging the Qualities of Things, Services, or People',
#  '4.A.2.a.2': 'Processing Information',
#  '4.A.2.a.3': 'Evaluating Information to Determine Compliance with Standards',
#  '4.A.2.a.4': 'Analyzing Data or Information',
#  '4.A.2.b.1': 'Making Decisions and Solving Problems',
#  '4.A.2.b.2': 'Thinking Creatively',
#  '4.A.2.b.3': 'Updating and Using Relevant Knowledge',
#  '4.A.2.b.4': 'Developing Objectives and Strategies',
#  '4.A.2.b.5': 'Scheduling Work and Activities',
#  '4.A.2.b.6': 'Organizing, Planning, and Prioritizing Work',
#  '4.A.3.a.1': 'Performing General Physical Activities',
#  '4.A.3.a.2': 'Handling and Moving Objects',
#  '4.A.3.a.3': 'Controlling Machines and Processes',
#  '4.A.3.a.4': 'Operating Vehicles, Mechanized Devices, or Equipment',
#  '4.A.3.b.1': 'Interacting With Computers',
#  '4.A.3.b.2': 'Drafting, Laying Out, and Specifying Technical Devices, Parts, and Equipment',
#  '4.A.3.b.4': 'Repairing and Maintaining Mechanical Equipment',
#  '4.A.3.b.5': 'Repairing and Maintaining Electronic Equipment',
#  '4.A.3.b.6': 'Documenting/Recording Information',
#  '4.A.4.a.1': 'Interpreting the Meaning of Information for Others',
#  '4.A.4.a.2': 'Communicating with Supervisors, Peers, or Subordinates',
#  '4.A.4.a.3': 'Communicating with Persons Outside Organization',
#  '4.A.4.a.4': 'Establishing and Maintaining Interpersonal Relationships',
#  '4.A.4.a.5': 'Assisting and Caring for Others',
#  '4.A.4.a.6': 'Selling or Influencing Others',
#  '4.A.4.a.7': 'Resolving Conflicts and Negotiating with Others',
#  '4.A.4.a.8': 'Performing for or Working Directly with the Public',
#  '4.A.4.b.1': 'Coordinating the Work and Activities of Others',
#  '4.A.4.b.2': 'Developing and Building Teams',
#  '4.A.4.b.3': 'Training and Teaching Others',
#  '4.A.4.b.4': 'Guiding, Directing, and Motivating Subordinates',
#  '4.A.4.b.5': 'Coaching and Developing Others',
#  '4.A.4.b.6': 'Provide Consultation and Advice to Others',
#  '4.A.4.c.1': 'Performing Administrative Activities',
#  '4.A.4.c.2': 'Staffing Organizational Units',
#  '4.A.4.c.3': 'Monitoring and Controlling Resources'}

# %%
#create dictionary of {task ids: task descriptions}
task_dict = pd.Series(tasks['Task'].values, index=tasks['Task ID']).to_dict()
task_dict
# Out:
# {8823: "Direct or coordinate an organization's financial or budget activities to fund operations, maximize investments, or increase efficiency.",
#  8831: 'Appoint department heads or managers and assign or delegate responsibilities to them.',
#  8825: 'Analyze operations to evaluate performance of a company or its staff in meeting objectives or to determine areas of potential cost reduction, program improvement, or policy change.',
#  8826: 'Direct, plan, or implement policies, objectives, or activities of organizations or businesses to ensure continuing operations, to maximize returns on investments, or to increase productivity.',
#  8827: 'Prepare budgets for approval, including those for funding or implementation of programs.',
#  8824: 'Confer with board members, organization officials, or staff members to discuss issues, coordinate activities, or resolve problems.',
#  8836: 'Implement corrective action plans to solve organizational or departmental problems.',
#  8832: 'Direct human resources activities, including the approval of human resource plans or activities, the selection of directors or other high-level staff, or establishment or organization of major departments.',
#  8835: 'Establish departmental responsibilities and coordinate functions among departments and sites.',
#  8833: 'Preside over or serve on boards of directors, management committees, or other governing boards.',
#  8829: 'Negotiate or approve contracts or agreements with suppliers, distributors, federal or state agencies, or other organizational entities.',
#  8837: 'Coordinate the development or implementation of budgetary control systems, recordkeeping systems, or other administrative control processes.',
#  8830: 'Review reports submitted by staff members to recommend approval or to suggest changes.',
#  8839: 'Deliver speeches, write articles, or present information at meetings or conventions to promote services, exchange ideas, or accomplish objectives.',
#  8843: 'Interpret and explain policies, rules, regulations, or laws to organizations, government or corporate officials, or individuals.',
#  8834: 'Prepare or present reports concerning activities, expenses, budgets, government statutes or rulings, or other items affecting businesses or program services.',
#  20461: 'Review and analyze legislation, laws, or public policy and recommend changes to promote or support interests of the general population or special groups.',
#  8846: 'Administer programs for selection of sites, construction of buildings, or provision of equipment or supplies.',
#  8848: 'Direct or conduct studies or research on issues affecting areas of responsibility.',
#  8828: 'Direct or coordinate activities of businesses or departments concerned with production, pricing, sales, or distribution of products.',
#  8844: 'Make presentations to legislative or other government committees regarding policies, programs, or budgets.',
#  8845: 'Refer major policy matters to elected representatives for final decisions.',
#  8847: 'Direct or coordinate activities of businesses involved with buying or selling investment products or financial services.',
#  8851: 'Conduct or direct investigations or hearings to resolve complaints or violations of laws or testify at such hearings.',
#  8838: 'Direct non-merchandising departments, such as advertising, purchasing, credit, or accounting.',
#  8853: 'Prepare bylaws approved by elected officials and ensure that bylaws are enforced.',
#  8840: 'Serve as liaisons between organizations, shareholders, and outside organizations.',
#  8849: 'Attend and participate in meetings of municipal councils or council committees.',
#  8852: 'Represent organizations or promote their objectives at official functions or delegate representatives to do so.',
#  8850: 'Organize or approve promotional campaigns.',
#  8842: 'Nominate citizens to boards or commissions.',
#  15384: 'Develop or execute strategies to address issues such as energy use, resource conservation, recycling, pollution reduction, waste elimination, transportation, education, and building design.',
#  15372: 'Supervise employees or volunteers working on sustainability projects.',
#  15376: 'Research environmental sustainability issues, concerns, or stakeholder interests.',
#  15381: 'Develop methodologies to assess the viability or success of sustainability initiatives.',
#  15382: 'Monitor and evaluate effectiveness of sustainability programs.',
#  15377: 'Evaluate and approve proposals for sustainability projects, considering factors such as cost effectiveness, technical feasibility, and integration with other initiatives.',
#  15380: 'Develop, or oversee the development of, marketing or outreach media for sustainability projects or events.',
#  15379: 'Develop, or oversee the development of, sustainability evaluation or monitoring systems.',
#  15370: 'Create and maintain sustainability program documents, such as schedules and budgets.',
#  15383: 'Direct sustainability program operations to ensure compliance with environmental or governmental regulations.',
#  15367: 'Identify educational, training, or other development opportunities for sustainability employees or volunteers.',
#  15378: 'Develop sustainability reports, presentations, or proposals for supplier, employee, academia, media, government, public interest, or other groups.',
#  15374: 'Review sustainability program objectives, progress, or status to ensure compliance with policies, standards, regulations, or laws.',
#  15375: 'Formulate or implement sustainability campaign or marketing strategies.',
#  15368: 'Identify and evaluate pilot projects or programs to enhance the sustainability research agenda.',
#  15369: 'Conduct sustainability- or environment-related risk assessments.',
#  15371: 'Write project proposals, grant applications, or other documents to pursue funding for environmental initiatives.',
#  15373: 'Write and distribute financial or environmental impact reports.',
#  20699: 'Review financial statements, sales or activity reports, or other performance data to measure productivity or goal achievement or to identify areas needing cost reduction or program improvement.',
#  933: 'Direct and coordinate activities of businesses or departments concerned with the production, pricing, sales, or distribution of products.',
#  20700: 'Direct administrative activities directly related to making products or providing services.',
#  20701: 'Prepare staff work schedules and assign specific duties.',
#  20702: 'Monitor suppliers to ensure that they efficiently and effectively provide needed goods or services within budgetary limits.',
#  20703: 'Direct or coordinate financial or budget activities to fund operations, maximize investments, or increase efficiency.',
#  20704: 'Establish or implement departmental policies, goals, objectives, or procedures in conjunction with board members, organization officials, or staff members.',
#  20705: 'Perform personnel functions such as selection, training, or evaluation.',
#  20706: 'Plan or direct activities such as sales promotions that require coordination with other department managers.',
#  20707: 'Set prices or credit terms for goods or services based on forecasts of customer demand.',
#  20708: 'Manage the movement of goods into and out of production facilities to ensure efficiency, effectiveness, or sustainability of operations.',
#  944: 'Perform sales floor work, such as greeting or assisting customers, stocking shelves, or taking inventory.',
#  945: 'Develop or implement product-marketing strategies, including advertising campaigns or sales promotions.',
#  948: 'Recommend locations for new facilities or oversee the remodeling or renovating of current facilities.',
#  19501: 'Implement or oversee environmental management or sustainability programs addressing issues such as recycling, conservation, or waste management.',
#  947: 'Direct non-merchandising departments of businesses, such as advertising or purchasing.',
#  949: 'Plan store layouts or design displays.',
#  15267: 'Analyze and understand the local and national implications of proposed legislation.',
#  15268: 'Appoint nominees to leadership posts, or approve such appointments.',
#  15269: 'Confer with colleagues to formulate positions and strategies pertaining to pending issues.',
#  15270: 'Debate the merits of proposals and bill amendments during floor sessions, following the appropriate rules of procedure.',
#  15271: 'Develop expertise in subject matters related to committee assignments.',
#  15272: 'Hear testimony from constituents, representatives of interest groups, board and commission members, and others with an interest in bills or issues under consideration.',
#  15273: 'Keep abreast of the issues affecting constituents by making personal visits and phone calls, reading local newspapers, and viewing or listening to local broadcasts.',
#  15274: 'Maintain knowledge of relevant national and international current events.',
#  15275: 'Make decisions that balance the perspectives of private citizens, public officials, and party leaders.',
#  15276: 'Negotiate with colleagues or members of other political parties in order to reconcile differing interests, and to create policies and agreements.',
#  15277: 'Prepare drafts of amendments, government policies, laws, rules, regulations, budgets, programs and procedures.',
#  15278: 'Read and review concerns of constituents or the general public and determine if governmental action is necessary.',
#  15279: 'Represent their parties in negotiations with political executives or members of other parties, and when speaking with the media.',
#  15280: 'Review bills in committee, and make recommendations about their future.',
#  15281: 'Seek federal funding for local projects and programs.',
#  15282: 'Serve on commissions, investigative panels, study groups, and committees in order to examine specialized areas and recommend action.',
#  15283: 'Vote on motions, amendments, and decisions on whether or not to report a bill out from committee to the assembly floor.',
#  15284: 'Write, prepare, and deliver statements for the Congressional Record.',
#  15285: 'Alert constituents of government actions and programs by way of newsletters, personal appearances at town meetings, phone calls, and individual meetings.',
#  15286: 'Attend receptions, dinners, and conferences to meet people, exchange views and information, and develop working relationships.',
#  15287: 'Conduct "head counts" to help predict the outcome of upcoming votes.',
#  15288: 'Determine campaign strategies for media advertising, positions on issues, and public appearances.',
#  15289: 'Encourage and support party candidates for political office.',
#  15290: 'Establish personal offices in local districts or states, and manage office staff.',
#  15291: 'Evaluate the structure, efficiency, activities, and performance of government agencies.',
#  15292: 'Organize and maintain campaign organizations and fundraisers, in order to raise money for election or re-election.',
#  15293: 'Oversee expense allowances, ensuring that accounts are balanced at the end of each fiscal year.',
#  15294: 'Promote the industries and products of their electoral districts.',
#  15295: 'Represent their government at local, national, and international meetings and conferences.',
#  15296: 'Speak to students to encourage and support the development of future political leaders.',
#  3224: 'Plan and prepare advertising and promotional material to increase sales of products or services, working with customers, company officials, sales departments, and advertising agencies.',
#  3226: 'Inspect layouts and advertising copy and edit scripts, audio and video tapes, and other promotional material for adherence to specifications.',
#  3225: 'Assist with annual budget development.',
#  3231: 'Confer with department heads or staff to discuss topics such as contracts, selection of advertising media, or product to be advertised.',
#  3242: 'Coordinate with the media to disseminate advertising.',
#  3227: 'Coordinate activities of departments, such as sales, graphic arts, media, finance, and research.',
#  3238: 'Plan and execute advertising policies and strategies for organizations.',
#  3237: 'Direct, motivate, and monitor the mobilization of a campaign team to advance campaign goals.',
#  3230: 'Gather and organize information to plan advertising campaigns.',
#  21038: 'Create media notices about events.',
#  3223: 'Prepare budgets and submit estimates for program costs as part of campaign plan development.',
#  3243: 'Contact organizations to explain services and facilities offered.',
#  3233: 'Monitor and analyze sales promotion results to determine cost effectiveness of promotion campaigns.',
#  3229: 'Identify and develop contacts for promotional campaigns and industry programs that meet identified buyer targets, such as dealers, distributors, or consumers.',
#  3239: 'Track program budgets, expenses, and campaign response rates to evaluate each campaign based on program objectives and industry norms.',
#  3234: 'Read trade journals and professional literature to stay informed on trends, innovations, and changes that affect media planning.',
#  18586: 'Manage sales team including setting goals, providing incentives, and evaluating employee performance.',
#  3228: 'Prepare and negotiate advertising and sales contracts.',
#  3235: 'Formulate plans to extend business with established accounts and to transact business as agent for advertising accounts.',
#  3241: 'Train and direct workers engaged in developing and producing advertisements.',
#  3232: 'Confer with clients to provide marketing or technical advice.',
#  3240: 'Assemble and communicate with a strong, diverse coalition of organizations or public figures, securing their cooperation, support, and action, to further campaign goals.',
#  3236: 'Provide presentation and product demonstration support during the introduction of new products and services to field staff and customers.',
#  3245: 'Represent company at trade association meetings to promote products.',
#  3244: 'Direct and coordinate product research and development.',
#  3246: 'Consult publications to learn about conventions and social functions and to organize prospect files for promotional purposes.',
#  19941: 'Analyze green product marketing or sales trends to forecast future conditions.',
#  15400: 'Analyze the effectiveness of marketing tactics or channels.',
#  19940: 'Attend or participate in conferences, community events, and promotional events related to green products or technologies.',
#  19939: 'Conduct research on consumer opinions and buying habits, and identify target audiences for green products, services, or technologies.',
#  19942: 'Develop branding or sales initiatives for green products, such as solar energy systems, green cleaning products, or products using renewable or recycled materials.',
#  19938: 'Develop communications materials, advertisements, presentations, or public relations initiatives to promote awareness of green products and technologies.',
#  19943: 'Develop comprehensive marketing strategies, using knowledge of green products and technologies, markets, and regulations.',
#  19937: 'Identify marketing channels for green products or services.',
#  19936: 'Revise existing marketing plans or campaigns for green products, technologies, or services.',
#  19935: 'Write marketing content for green product web sites, brochures, or other communication media.',
#  15401: 'Analyze regional energy markets, including energy pricing, market structures, energy generation competition, and energy transmission constraints.',
#  19944: 'Coordinate with other marketing team members and workers such as graphic artists to develop and implement marketing programs.',
#  15389: 'Devise or evaluate methods and procedures for collecting data, such as surveys, opinion polls, and questionnaires.',
#  19934: 'Generate or identify sales leads for green products and technologies.',
#  15387: 'Maintain portfolios of marketing campaigns, strategies, and other marketing products or ideas.',
#  19933: 'Monitor green-related industry statistics or literature to identify trends.',
#  951: 'Identify, develop, or evaluate marketing strategy, based on knowledge of establishment objectives, market characteristics, and cost and markup factors.',
#  20709: 'Formulate, direct, or coordinate marketing activities or policies to promote products or services, working with advertising or promotion managers.',
#  952: 'Evaluate the financial aspects of product development, such as budgets, expenditures, research and development appropriations, or return-on-investment and profit-loss projections.',
#  950: 'Develop pricing strategies, balancing firm objectives and customer satisfaction.',
#  957: 'Compile lists describing product or service offerings.',
#  954: 'Direct the hiring, training, or performance evaluations of marketing or sales staff and oversee their daily activities.',
#  956: 'Consult with product development personnel on product specifications such as design, color, or packaging.',
#  958: 'Use sales forecasting or strategic planning to ensure the sale and profitability of products, lines, or services, analyzing business developments and monitoring market trends.',
#  955: 'Negotiate contracts with vendors or distributors to manage product distribution, establishing distribution networks or developing distribution strategies.',
#  961: 'Coordinate or participate in promotional activities or trade shows, working with developers, advertisers, or production managers, to market products or services.',
#  963: 'Initiate market research studies or analyze their findings.',
#  960: 'Confer with legal staff to resolve problems, such as copyright infringement or royalty sharing with outside producers or distributors.',
#  964: 'Consult with buying personnel to gain advice regarding the types of products or services expected to be in demand.',
#  19502: 'Consult with buying personnel to gain advice regarding environmentally sound or sustainable products.',
#  965: 'Conduct economic or commercial surveys to identify potential markets for products or services.',
#  19505: 'Recommend modifications to products, packaging, production processes, or other characteristics to improve the environmental soundness or sustainability of products.',
#  962: 'Advise business or other groups on local, national, or international factors affecting the buying or selling of products or services.',
#  959: 'Select products or accessories to be displayed at trade or special production shows.',
#  19503: 'Develop business cases for environmental marketing strategies.',
#  19504: 'Integrate environmental information into product or company marketing strategies, policies, or activities.',
#  3: 'Direct and coordinate activities involving sales of manufactured products, services, commodities, real estate or other subjects of sale.',
#  1: 'Resolve customer complaints regarding sales and service.',
#  5: 'Review operational records and reports to project sales and determine profitability.',
#  14: 'Oversee regional and local sales managers and their staffs.',
#  4: 'Determine price schedules and discount rates.',
#  9: 'Prepare budgets and approve budget expenditures.',
#  2: 'Monitor customer preferences to determine focus of sales efforts.',
#  11: 'Plan and direct staffing, training, and performance evaluations to develop and control sales and service programs.',
#  6: 'Direct, coordinate, and review activities in sales and service accounting and record-keeping, and in receiving and shipping operations.',
#  15: 'Direct clerical staff to keep records of export correspondence, bid requests, and credit collections, and to maintain current information on tariffs, licenses, and restrictions.',
#  8: 'Advise dealers and distributors on policies and operating procedures to ensure functional effectiveness of business.',
#  7: 'Confer or consult with department heads to plan advertising services and to secure information on equipment and customer specifications.',
#  10: 'Represent company at trade association meetings to promote products.',
#  13: 'Confer with potential customers regarding equipment needs and advise customers on types of equipment to purchase.',
#  17: 'Assess marketing potential of new and existing store locations, considering statistics and expenditures.',
#  12: 'Visit franchised dealers to stimulate interest in establishment or expansion of leasing programs.',
#  16: 'Direct foreign sales and service outlets of an organization.',
#  18462: 'Identify main client groups and audiences, determine the best way to communicate publicity information to them, and develop and implement a communication plan.',
#  3249: "Develop and maintain the company's corporate image and identity, which includes the use of logos and signage.",
#  3251: 'Manage special events, such as sponsorship of races, parties introducing new products, or other activities the firm supports, to gain public attention through the media without advertising directly.',
#  3248: 'Write interesting and effective press releases, prepare information for media kits, and develop and maintain company internet or intranet web pages.',
#  20939: 'Design and edit promotional publications, such as brochures.',
#  18461: 'Establish and maintain effective working relationships with clients, government officials, and media representatives and use these relationships to develop new business opportunities.',
#  3254: 'Evaluate advertising and promotion programs for compatibility with public relations efforts.',
#  3261: 'Facilitate consumer relations or the relationship between parts of the company, such as the managers and employees, or different branch offices.',
#  3260: 'Establish goals for soliciting funds, develop policies for collection and safeguarding of contributions, and coordinate disbursement of funds.',
#  3253: 'Assign, supervise, and review the activities of public relations staff.',
#  3250: 'Manage communications budgets.',
#  3252: 'Draft speeches for company executives and arrange interviews and other forms of contact for them.',
#  3259: "Respond to requests for information about employers' activities or status.",
#  3257: 'Direct activities of external agencies, establishments, and departments that develop and implement communication strategies and information programs.',
#  20940: 'Develop, implement, and maintain crisis communication plans.',
#  3258: 'Formulate policies and procedures related to public information programs, working with public relations executives.',
#  3264: 'Produce films and other video products, regulate their distribution, and operate film library.',
#  3256: 'Confer with labor relations managers to develop internal communications that keep employees informed of company activities.',
#  3265: 'Observe and report on social, economic, and political trends that might affect employers.',
#  3262: 'Maintain company archives.',
#  3263: 'Manage in-house communication courses.',
#  18: 'Monitor the facility to ensure that it remains safe, secure, and well-maintained.',
#  21: 'Prepare and review operational reports and schedules to ensure accuracy and efficiency.',
#  20: 'Set goals and deadlines for the department.',
#  23: 'Acquire, distribute and store supplies.',
#  22: 'Analyze internal processes and recommend and implement procedural or policy changes to improve operations, such as supply changes or the disposal of records.',
#  30: 'Conduct classes to teach procedures to staff.',
#  24: 'Plan, administer, and control budgets for contracts, equipment, and supplies.',
#  26: 'Hire and terminate clerical and administrative personnel.',
#  19: 'Direct or coordinate the supportive services department of a business, agency, or organization.',
#  25: 'Oversee construction and renovation projects to improve efficiency and to ensure that facilities meet environmental, health, and security standards, and comply with government regulations.',
#  27: 'Oversee the maintenance and repair of machinery, equipment, and electrical and mechanical systems.',
#  28: 'Manage leasing of facility space.',
#  29: 'Participate in architectural and engineering planning and design, including space and installation management.',
#  31: 'Dispose of, or oversee the disposal of, surplus or unclaimed property.',
#  968: 'Direct daily operations of department, analyzing workflow, establishing priorities, developing standards and setting deadlines.',
#  975: 'Meet with department heads, managers, supervisors, vendors, and others, to solicit cooperation and resolve problems.',
#  978: 'Review project plans to plan and coordinate project activity.',
#  969: 'Assign and review the work of systems analysts, programmers, and other computer-related workers.',
#  15198: 'Provide users with technical support for computer problems.',
#  971: 'Develop computer information resources, providing for data security and control, strategic computing, and disaster recovery.',
#  977: 'Recruit, hire, train and supervise staff, or participate in staffing decisions.',
#  970: 'Stay abreast of advances in technology.',
#  967: 'Consult with users, management, vendors, and technicians to assess computing needs and system requirements.',
#  976: 'Develop and interpret organizational goals, policies, and procedures.',
#  973: "Evaluate the organization's technology use and needs and recommend improvements, such as hardware and software upgrades.",
#  972: 'Review and approve all systems charts and programs prior to their implementation.',
#  980: 'Prepare and review operational reports or project progress reports.',
#  979: 'Evaluate data processing proposals to assess project feasibility and requirements.',
#  974: 'Control operational budget and expenditures.',
#  981: 'Purchase necessary equipment.',
#  966: 'Manage backup, security and user help systems.',
#  8857: 'Supervise employees performing financial reporting, accounting, billing, collections, payroll, and budgeting duties.',
#  8865: 'Coordinate and direct the financial planning, budgeting, procurement, or investment activities of all or part of an organization.',
#  8866: 'Develop internal control policies, guidelines, and procedures for activities such as budget administration, cash and credit management, and accounting.',
#  8859: 'Maintain current knowledge of organizational policies and procedures, federal and state policies and directives, and current accounting standards.',
#  8856: 'Prepare or direct preparation of financial statements, business activity reports, financial position forecasts, annual budgets, or reports required by regulatory agencies.',
#  8869: 'Provide direction and assistance to other organizational units regarding accounting and budgeting policies and procedures and efficient control and utilization of financial resources.',
#  8867: 'Analyze the financial details of past, present, and expected operations to identify development opportunities and areas where improvement is needed.',
#  8868: 'Advise management on short-term and long-term financial objectives, policies, and actions.',
#  20168: 'Monitor financial activities and details, such as cash flow and reserve levels, to ensure that all legal and regulatory requirements are met.',
#  8870: 'Evaluate needs for procurement of funds and investment of surpluses and make appropriate recommendations.',
#  8863: 'Monitor and evaluate the performance of accounting and other financial staff, recommending and implementing personnel actions, such as promotions and dismissals.',
#  8864: 'Develop and maintain relationships with banking, insurance, and external accounting personnel to facilitate financial activities.',
#  8861: 'Receive, record, and authorize requests for disbursements in accordance with company policies and procedures.',
#  8858: 'Delegate authority for the receipt, disbursement, banking, protection, and custody of funds, securities, and financial instruments.',
#  8860: 'Conduct or coordinate audits of company accounts and financial transactions to ensure compliance with state and federal requirements and statutes.',
#  8871: 'Lead staff training and development in budgeting and financial management areas.',
#  8855: 'Prepare and file annual tax returns or prepare financial information so that outside accountants can complete tax returns.',
#  8873: 'Compute, withhold, and account for all payroll deductions.',
#  20169: "Handle all aspects of employee insurance, benefits, and casualty programs, including monitoring changes in health insurance regulations and creating budgets for benefits and worker's compensation.",
#  8872: 'Receive cash and checks and make deposits.',
#  8874: 'Perform tax planning work.',
#  8875: 'Determine depreciation rates to apply to capitalized items and advise management on actions regarding the purchase, lease, or disposal of such items.',
#  8878: 'Plan, direct, or coordinate the activities of workers in branches, offices, or departments of establishments, such as branch banks, brokerage firms, risk and insurance departments, or credit departments.',
#  8876: 'Establish and maintain relationships with individual or business customers or provide assistance with problems these customers may encounter.',
#  20462: 'Recruit staff members.',
#  8886: 'Prepare operational or risk reports for management analysis.',
#  8891: 'Evaluate data pertaining to costs to plan budgets.',
#  20463: 'Oversee training programs.',
#  8877: 'Examine, evaluate, or process loan applications.',
#  8882: 'Approve, reject, or coordinate the approval or rejection of lines of credit or commercial, real estate, or personal loans.',
#  8879: 'Oversee the flow of cash or financial instruments.',
#  8883: 'Prepare financial or regulatory reports required by laws, regulations, or boards of directors.',
#  8894: 'Develop or analyze information to assess the current or future financial status of firms.',
#  8890: 'Communicate with stockholders or other investors to provide information or to raise capital.',
#  8887: 'Evaluate financial reporting systems, accounting or collection procedures, or investment activities and make recommendations for changes to procedures, operating systems, budgets, or other financial control functions.',
#  8892: 'Analyze and classify risks and investments to determine their potential impacts on companies.',
#  8881: 'Network within communities to find and attract new business.',
#  8885: 'Review collection reports to determine the status of collections and the amounts of outstanding balances.',
#  8884: 'Establish procedures for custody or control of assets, records, loan collateral, or securities to ensure safekeeping.',
#  8888: 'Plan, direct, and coordinate risk and insurance programs of establishments to control risks and losses.',
#  8893: 'Review reports of securities transactions or price lists to analyze market conditions.',
#  8895: 'Direct insurance negotiations, select insurance brokers or carriers, and place insurance.',
#  8889: 'Submit delinquent accounts to attorneys or outside agencies for collection.',
#  34: 'Review processing schedules or production orders to make decisions concerning inventory requirements, staffing requirements, work procedures, or duty assignments, considering budgetary limitations and time constraints.',
#  32: 'Direct or coordinate production, processing, distribution, or marketing activities of industrial organizations.',
#  40: 'Develop or implement production tracking or quality control systems, analyzing production, quality control, maintenance, or other operational reports, to detect production problems.',
#  35: 'Review operations and confer with technical or administrative staff to resolve production or processing problems.',
#  36: 'Hire, train, evaluate, or discharge staff or resolve personnel grievances.',
#  38: 'Prepare and maintain production reports or personnel records.',
#  39: 'Set and monitor product standards, examining samples of raw products or directing testing during processing, to ensure finished products are of prescribed quality.',
#  33: 'Develop budgets or approve expenditures for supplies, materials, or human resources, ensuring that materials, labor, or equipment are used efficiently to meet production targets.',
#  37: 'Initiate or coordinate inventory or cost control programs.',
#  43: 'Coordinate or recommend procedures for facility or equipment maintenance or modification, including the replacement of machines.',
#  41: 'Review plans and confer with research or support staff to develop new products or processes.',
#  42: 'Institute employee suggestion or involvement programs.',
#  44: 'Maintain current knowledge of the quality control field, relying on current literature pertaining to materials use, technological advances, or statistical studies.',
#  45: 'Negotiate materials prices with suppliers.',
#  15411: 'Collect and analyze production samples to evaluate quality.',
#  15428: 'Analyze quality control test results and provide feedback and interpretation to production management or staff.',
#  15405: 'Stop production if serious product defects are present.',
#  15430: 'Monitor performance of quality control systems to ensure effectiveness and efficiency.',
#  15427: 'Communicate quality control information to all relevant organizational departments, outside vendors, or contractors.',
#  15421: 'Instruct staff in quality control and analytical procedures.',
#  15416: 'Produce reports regarding nonconformance of products or processes, daily production quality, root cause analyses, or quality trends.',
#  15417: 'Participate in the development of product specifications.',
#  15407: 'Review statistical studies, technological advances, or regulatory standards and trends to stay abreast of issues in the field of quality control.',
#  15422: 'Identify critical points in the manufacturing process and specify sampling procedures to be used at these points.',
#  15425: 'Create and implement inspection and testing criteria or procedures.',
#  15429: 'Oversee workers including supervisors, inspectors, or laboratory workers engaged in testing activities.',
#  15423: 'Document testing procedures, methodologies, or criteria.',
#  15415: 'Review and update standard operating procedures or quality assurance manuals.',
#  15420: 'Identify quality problems or areas for improvement and recommend solutions.',
#  15413: 'Verify that raw materials, purchased parts or components, in-process samples, and finished products meet established testing and inspection standards.',
#  15414: 'Review quality documentation necessary for regulatory submissions and inspections.',
#  15408: 'Generate and maintain quality control operating budgets.',
#  15424: 'Direct the tracking of defects, test results, or other regularly reported quality control data.',
#  15409: 'Evaluate new testing and sampling methodologies or technologies to determine usefulness.',
#  15431: 'Direct product testing activities throughout production cycles.',
#  15419: 'Instruct vendors or contractors on quality guidelines, testing procedures, or ways to eliminate deficiencies.',
#  15410: 'Coordinate the selection and implementation of quality control equipment, such as inspection gauges.',
#  15418: 'Monitor development of new products to help identify possible problems for mass production.',
#  15426: 'Confer with marketing and sales departments to define client requirements and expectations.',
#  15406: 'Review and approve quality plans submitted by contractors.',
#  15412: 'Audit and inspect subcontractor facilities including external laboratories.',
#  15446: 'Supervise employees in geothermal power plants or well fields.',
#  15447: 'Oversee geothermal plant operations, maintenance, and repairs to ensure compliance with applicable standards or regulations.',
#  15434: 'Communicate geothermal plant conditions to employees.',
#  15443: 'Identify and evaluate equipment, procedural, or conditional inefficiencies involving geothermal plant systems.',
#  15439: 'Perform or direct the performance of preventative maintenance on geothermal plant equipment.',
#  15448: 'Inspect geothermal plant or injection well fields to verify proper equipment operations.',
#  15445: 'Develop or manage budgets for geothermal operations.',
#  15433: 'Select and implement corrosion control or mitigation systems for geothermal plants.',
#  15444: 'Develop operating plans and schedules for geothermal operations.',
#  15436: 'Record, review, or maintain daily logs, reports, maintenance, and other records associated with geothermal operations.',
#  15441: 'Monitor geothermal operations, using programmable logic controllers.',
#  15432: 'Conduct well field site assessments.',
#  15442: 'Identify opportunities to improve plant electrical equipment, controls, or process control methodologies.',
#  15437: 'Prepare environmental permit applications or compliance reports.',
#  15440: 'Negotiate interconnection agreements with other utilities.',
#  15438: 'Obtain permits for constructing, upgrading, or operating geothermal power plants.',
#  15435: 'Troubleshoot and make minor repairs to geothermal plant instrumentation or electrical systems.',
#  15454: 'Supervise production employees in the manufacturing of biofuels, such as biodiesel or ethanol.',
#  15462: 'Manage operations at biofuels power generation facilities, including production, shipping, maintenance, or quality assurance activities.',
#  15450: 'Provide direction to employees to ensure compliance with biofuels plant safety, environmental, or operational standards and regulations.',
#  15453: 'Confer with technical and supervisory personnel to report or resolve conditions affecting biofuels plant safety, operational efficiency, and product quality.',
#  15456: 'Review logs, datasheets, or reports to ensure adequate production levels or to identify abnormalities with biofuels production equipment or processes.',
#  15458: 'Monitor meters, flow gauges, or other real-time data to ensure proper operation of biofuels production equipment, implementing corrective measures as needed.',
#  15461: 'Adjust temperature, pressure, vacuum, level, flow rate, or transfer of biofuels to maintain processes at required levels.',
#  15449: 'Provide training to subordinate or new employees to improve biofuels plant safety or increase the production of biofuels.',
#  15455: 'Shut down and restart biofuels plant or equipment in emergency situations or for equipment maintenance, repairs, or replacements.',
#  15451: 'Monitor transportation and storage of flammable or other potentially dangerous feedstocks or products to ensure adherence to safety guidelines.',
#  15452: 'Draw samples of biofuels products or secondary by-products for quality control testing.',
#  15460: 'Approve proposals for the acquisition, replacement, or repair of biofuels processing equipment or the implementation of new production processes.',
#  15457: 'Prepare and manage biofuels plant or unit budgets.',
#  15459: 'Conduct cost, material, and efficiency studies for biofuels production plants or operations.',
#  15470: 'Review logs, datasheets, or reports to ensure adequate production levels and safe production environments or to identify abnormalities with power production equipment or processes.',
#  15471: 'Review biomass operations performance specifications to ensure compliance with regulatory requirements.',
#  15478: 'Supervise biomass plant or substation operations, maintenance, repair, or testing activities.',
#  15473: 'Prepare and manage biomass plant budgets.',
#  15468: 'Supervise operations or maintenance employees in the production of power from biomass, such as wood, coal, paper sludge, or other waste or refuse.',
#  15479: 'Monitor the operating status of biomass plants by observing control system parameters, distributed control systems, switchboard gauges, dials, or other indicators.',
#  15476: 'Inspect biomass gasification processes, equipment, and facilities for ways to maximize capacity and minimize operating costs.',
#  15480: 'Conduct field inspections of biomass plants, stations, or substations to ensure normal and safe operating conditions.',
#  15474: 'Plan and schedule plant activities, such as wood, waste, or refuse fuel deliveries, ash removal, and regular maintenance.',
#  15477: 'Evaluate power production or demand trends to identify opportunities for improved operations.',
#  15472: 'Prepare reports on biomass plant operations, status, maintenance, and other information.',
#  15464: 'Manage parts and supply inventories for biomass plants.',
#  15465: 'Monitor and operate communications systems, such as mobile radios.',
#  15466: 'Compile and record operational data on forms or in log books.',
#  15469: 'Shut down and restart biomass power plants or equipment in emergency situations or for equipment maintenance, repairs, or replacements.',
#  15463: 'Test, maintain, or repair electrical power distribution machinery or equipment, using hand tools, power tools, and testing devices.',
#  15467: 'Adjust equipment controls to generate specified amounts of electrical power.',
#  15475: 'Operate controls to start, stop, or regulate biomass-fueled generators, generator units, boilers, engines, or auxiliary systems.',
#  15501: 'Monitor and control liquid or gas landfill extraction systems.',
#  15500: 'Oversee gas collection landfill operations, including leachate and gas management or rail operations.',
#  15498: 'Develop or enforce procedures for normal operation, start-up, or shut-down of methane gas collection systems.',
#  15499: 'Evaluate landfill gas collection service requirements to meet operational plans and productivity goals.',
#  15497: 'Implement landfill operational and emergency procedures.',
#  15496: 'Inspect landfill or conduct site audits to ensure adherence to safety and environmental regulations.',
#  15495: 'Maintain records for landfill gas collection systems to demonstrate compliance with safety and environmental laws, regulations, or policies.',
#  15494: 'Monitor gas collection systems emissions data, including biomethane or nitrous oxide levels.',
#  15492: 'Monitor landfill permit requirements for updates.',
#  15493: 'Operate computerized control panels to manage gas compression operations.',
#  15491: 'Optimize gas collection landfill operational costs and productivity consistent with safety and environmental rules and regulations.',
#  15490: 'Oversee landfill gas collection system construction, maintenance, and repair activities.',
#  15488: 'Prepare and manage landfill gas collection system budgets.',
#  15489: 'Prepare soil reports as required by regulatory or permitting agencies.',
#  15487: 'Supervise landfill, well field, and other subordinate employees.',
#  15486: 'Read meters, gauges, or automatic recording devices at specified intervals to verify gas collection systems operating conditions.',
#  15485: 'Coordinate the repair, overhaul, or routine maintenance of diesel engines used in landfill operations.',
#  15484: 'Diagnose or troubleshoot gas collection equipment and programmable logic controller (PLC) systems.',
#  15483: 'Prepare reports on landfill operations and gas collection system productivity or efficiency.',
#  15482: 'Recommend or implement practices to reduce turnaround time for trucks in and out of landfill site.',
#  15481: 'Track volume and weight of landfill waste.',
#  15520: 'Direct operations, maintenance, or repair of hydroelectric power facilities.',
#  15515: 'Identify and communicate power system emergencies.',
#  15512: 'Maintain records of hydroelectric facility operations, maintenance, or repairs.',
#  15509: 'Perform or direct preventive or corrective containment or cleanup to protect the environment.',
#  15513: 'Monitor or inspect hydroelectric equipment, such as hydro-turbines, generators, or control systems.',
#  15514: 'Inspect hydroelectric facilities, including switchyards, control houses, or relay houses, for normal operation or adherence to safety standards.',
#  15519: 'Supervise or monitor hydroelectric facility operations to ensure that generation or mechanical equipment conform to applicable regulations or standards.',
#  15508: 'Plan or coordinate hydroelectric production operations to meet customer requirements.',
#  15518: 'Check hydroelectric operations for compliance with prescribed operating limits, such as loads, voltages, temperatures, lines, or equipment.',
#  15504: 'Develop or implement projects to improve efficiency, economy, or effectiveness of hydroelectric plant operations.',
#  15503: 'Provide technical direction in the erection or commissioning of hydroelectric equipment or supporting electrical or mechanical systems.',
#  15505: 'Supervise hydropower plant equipment installations, upgrades, or maintenance.',
#  15507: 'Plan or manage hydroelectric plant upgrades.',
#  15506: 'Respond to problems related to ratepayers, water users, power users, government agencies, educational institutions, or other private or public power resource interests.',
#  15516: 'Develop or review budgets, annual plans, power contracts, power rates, standing operating procedures, power reviews, or engineering studies.',
#  15502: 'Develop or implement policy evaluation procedures for hydroelectric generation activities.',
#  15510: 'Operate energized high- or low-voltage hydroelectric power transmission system substations, according to procedures and safety requirements.',
#  15517: 'Create or enforce hydrostation voltage schedules.',
#  15511: 'Negotiate power generation contracts with other public or private utilities.',
#  1030: 'Represent companies in negotiating contracts and formulating policies with suppliers.',
#  21039: 'Develop cost reduction strategies and savings plans.',
#  1027: 'Develop and implement purchasing and contract management instructions, policies, and procedures.',
#  1033: 'Prepare bid awards requiring board approval.',
#  1032: 'Direct and coordinate activities of personnel engaged in buying, selling, and distributing materials, equipment, machinery, and supplies.',
#  1021: 'Locate vendors of materials, equipment or supplies, and interview them to determine product availability and terms of sales.',
#  1024: 'Interview and hire staff, and oversee staff training.',
#  1022: 'Prepare and process requisitions and purchase orders for supplies and equipment.',
#  1031: 'Review, evaluate, and approve specifications for issuing and awarding bids.',
#  1023: 'Control purchasing department budgets.',
#  1025: 'Review purchase order claims and contracts for conformance to company policy.',
#  1029: 'Resolve vendor or contractor grievances, and claims against suppliers.',
#  1035: 'Administer online purchasing systems.',
#  1020: 'Maintain records of goods ordered and received.',
#  1026: 'Analyze market and delivery systems to assess present and future material availability.',
#  1028: 'Participate in the development of specifications for equipment, products, or substitute materials.',
#  1034: 'Prepare reports regarding market conditions and merchandise costs.',
#  1036: 'Arrange for disposal of surplus materials.',
#  1038: 'Plan, organize, or manage the work of subordinate staff to ensure that the work is accomplished in a manner consistent with organizational requirements.',
#  1037: 'Direct activities related to dispatching, routing, or tracking transportation vehicles, such as aircraft or railroad cars.',
#  20464: 'Monitor operations to ensure that staff members comply with administrative policies and procedures, safety rules, union contracts, environmental policies, or government regulations.',
#  1040: 'Serve as contact persons for all workers within assigned territories.',
#  20465: 'Implement schedule or policy changes for transportation services.',
#  1046: 'Monitor spending to ensure that expenses are consistent with approved budgets.',
#  1044: 'Promote safe work activities by conducting safety audits, attending company safety meetings, or meeting with individual staff members.',
#  1055: 'Prepare management recommendations, such as proposed fee and tariff increases or schedule changes.',
#  1039: 'Direct investigations to verify and resolve customer or shipper complaints.',
#  20466: 'Direct or coordinate the activities of operations department to obtain use of equipment, facilities, or human resources.',
#  1050: 'Analyze expenditures and other financial information to develop plans, policies, or budgets for increasing profits or improving services.',
# ...
#  18838: 'Plan and implement changes to service offerings to meet community needs or increase funeral home revenues.',
#  18834: 'Direct or monitor administrative, support, repair, or maintenance services for funeral homes.',
#  18851: 'Schedule work hours for funeral home or contract employees.',
#  18844: 'Set marketing, sales, or other financial goals for funeral service establishments and monitor progress toward these goals.',
#  18848: 'Explain goals, policies, or procedures to staff members.',
#  18846: 'Complete and maintain records such as state-required documents, tracking documents, or product inventories.',
#  18847: 'Evaluate the performance of vendors, contract employees, or other service providers to ensure quality and cost-efficiency.',
#  18845: 'Set prices or credit terms for funeral products or services.',
#  18841: 'Review financial statements, sales or activity reports, or other performance data to identify opportunities for cost reductions or service improvements.',
#  18849: 'Identify skill development needs for funeral home staff.',
#  18830: 'Attend or make presentations at community events to promote funeral home services or build community relationships.',
#  18839: 'Plan and implement sales promotions or other marketing strategies and activities for funeral home operations.',
#  18850: 'Interview and hire new employees.',
#  18831: 'Conduct market research and analyze industry trends.',
#  7186: 'Remove suspected cheaters, such as card counters or other players who may have systems that shift the odds of winning to their favor.',
#  7189: 'Circulate among gaming tables to ensure that operations are conducted properly, that dealers follow house rules, or that players are not cheating.',
#  7190: 'Explain and interpret house rules, such as game rules or betting limits.',
#  7196: 'Track supplies of money to tables and perform any required paperwork.',
#  7185: 'Resolve customer complaints regarding problems such as payout errors.',
#  20472: 'Market or promote the casino to bring in business.',
#  7193: 'Prepare work schedules and station arrangements and keep attendance records.',
#  7197: 'Set and maintain a bank and table limit for each game.',
#  7187: 'Maintain familiarity with all games used at a facility, as well as strategies or tricks employed in those games.',
#  7191: 'Monitor staffing levels to ensure that games and tables are adequately staffed for each shift, arranging for staff rotations and breaks and locating substitute employees as necessary.',
#  7199: 'Review operational expenses, budget estimates, betting accounts, or collection reports for accuracy.',
#  7188: 'Train new workers or evaluate their performance.',
#  7192: 'Interview and hire workers.',
#  7194: 'Direct the distribution of complimentary hotel rooms, meals, or other discounts or free items given to players, based on their length of play and betting totals.',
#  7195: 'Establish policies on issues such as the type of gambling offered and the odds, the extension of credit, or the serving of food and beverages.',
#  7200: 'Record, collect, or pay off bets, issuing receipts as necessary.',
#  7201: 'Direct the compilation of summary sheets that show wager amounts and payoffs for races or events.',
#  7198: 'Monitor credit extended to players.',
#  7202: 'Notify board attendants of table vacancies so that waiting patrons can play.',
#  1105: "Answer inquiries pertaining to hotel policies and services, and resolve occupants' complaints.",
#  1108: 'Participate in financial activities, such as the setting of room rates, the establishment of budgets, and the allocation of funds to departments.',
#  1109: 'Confer and cooperate with other managers to ensure coordination of hotel activities.',
#  1104: 'Greet and register guests.',
#  18599: 'Monitor the revenue activity of the hotel or facility.',
#  1111: 'Manage and maintain temporary or permanent lodging facilities.',
#  1113: 'Train staff members.',
#  1112: "Observe and monitor staff performance to ensure efficient operations and adherence to facility's policies and procedures.",
#  1107: 'Coordinate front-office activities of hotels or motels, and resolve problems.',
#  1116: 'Inspect guest rooms, public areas, and grounds for cleanliness and appearance.',
#  1106: 'Assign duties to workers, and schedule shifts.',
#  1123: 'Receive and process advance registration payments, mail letters of confirmation, or return checks when registrations cannot be accepted.',
#  1118: 'Interview and hire applicants.',
#  1119: 'Purchase supplies, and arrange for outside services, such as deliveries, laundry, maintenance and repair, and trash collection.',
#  18600: 'Collect payments and record data pertaining to funds and expenditures.',
#  1115: 'Develop and implement policies and procedures for the operation of a department or establishment.',
#  1117: 'Prepare required paperwork pertaining to departmental functions.',
#  1114: 'Show, rent, or assign accommodations.',
#  1121: 'Perform marketing and public relations activities.',
#  1122: 'Organize and coordinate the work of staff and convention personnel for meetings to be held at a particular facility.',
#  1125: 'Provide assistance to staff members by inspecting rooms, setting tables, or doing laundry.',
#  1120: 'Arrange telephone answering services, deliver mail and packages, or answer questions regarding locations for eating and entertainment.',
#  1124: 'Meet with clients to schedule and plan details of conventions, banquets, receptions and other functions.',
#  1126: 'Book tickets for guests for local tours and attractions.',
#  49: 'Develop and maintain computerized record management systems to store and process data, such as personnel activities and information, and to produce reports.',
#  46: 'Direct, supervise and evaluate work activities of medical, nursing, technical, clerical, service, maintenance, and other personnel.',
#  48: 'Direct or conduct recruitment, hiring, and training of personnel.',
#  50: 'Develop and implement organizational policies and procedures for the facility or medical unit.',
#  51: 'Conduct and administer fiscal operations, including accounting, planning budgets, authorizing expenditures, establishing rates for services, and coordinating financial reporting.',
#  55: 'Maintain awareness of advances in medicine, computerized diagnostic and treatment equipment, data processing technology, government regulations, health insurance changes, and financing options.',
#  58: 'Plan, implement and administer programs and services in a health care or medical facility, including personnel administration, training, and coordination of medical, nursing and physical plant staff.',
#  57: 'Prepare activity reports to inform management of the status and implementation plans of programs, services, and quality initiatives.',
#  52: 'Establish work schedules and assignments for staff, according to workload, space and equipment availability.',
#  53: 'Maintain communication between governing boards, medical staff, and department heads by attending board meetings and coordinating interdepartmental functioning.',
#  47: 'Establish objectives and evaluative or operational criteria for units they manage.',
#  61: 'Review and analyze facility activities and data to aid planning and cash and risk management and to improve service utilization.',
#  56: 'Manage change in integrated health care delivery systems, such as work restructuring, technological innovations, and shifts in the focus of care.',
#  63: 'Develop instructional materials and conduct in-service and community-based educational programs.',
#  54: 'Monitor the use of diagnostic services, inpatient beds, facilities, and staff to ensure effective use of resources and assess the need for additional staff, equipment, and services.',
#  60: 'Inspect facilities and recommend building or equipment modifications to ensure emergency readiness and compliance to access, safety, and sanitation regulations.',
#  62: 'Develop or expand and implement medical programs or health services that promote research, rehabilitation, and community health.',
#  59: 'Consult with medical, business, and community groups to discuss service problems, respond to community needs, enhance public relations, coordinate activities and plans, and promote health programs.',
#  7203: 'Confer with scientists, engineers, regulators, or others to plan or review projects or to provide technical assistance.',
#  7204: 'Develop client relationships and communicate with clients to explain proposals, present research findings, establish specifications, or discuss project status.',
#  7205: 'Plan or direct research, development, or production activities.',
#  7208: 'Review project activities and prepare and review research, testing, or operational reports.',
#  7210: 'Determine scientific or technical goals within broad outlines provided by top management and make detailed plans to accomplish these goals.',
#  7211: 'Develop or implement policies, standards, or procedures for the architectural, scientific, or technical work performed to ensure regulatory compliance or operations enhancement.',
#  7209: 'Hire, supervise, or evaluate engineers, technicians, researchers, or other staff.',
#  7207: 'Design or coordinate successive phases of problem analysis, solution proposals, or testing.',
#  7215: 'Recruit personnel or oversee the development or maintenance of staff competence.',
#  7206: 'Prepare project proposals.',
#  7214: 'Conduct own research in field of expertise.',
#  7217: 'Prepare and administer budgets, approve and review expenditures, and prepare financial reports.',
#  7218: 'Make presentations at professional meetings to further knowledge in the field.',
#  7212: 'Develop innovative technology or train staff for its implementation.',
#  7213: 'Provide for stewardship of plant or animal resources or habitats, studying land use, monitoring animal populations, or providing shelter, resources, or medical treatment for animals.',
#  7216: 'Advise or assist in obtaining patents or meeting other legal requirements.',
#  15614: 'Maintain required records of study activity including case report forms, drug dispensation records, or regulatory forms.',
#  15597: 'Oversee subject enrollment to ensure that informed consent is properly obtained and documented.',
#  15613: 'Monitor study activities to ensure compliance with protocols and with all relevant local, federal, and state regulatory and institutional polices.',
#  15594: 'Record adverse event and side effect data and confer with investigators regarding the reporting of events to oversight agencies.',
#  15610: 'Assess eligibility of potential subjects through methods such as screening interviews, reviews of medical records, or discussions with physicians and nurses.',
#  15585: 'Prepare for or participate in quality assurance audits conducted by study sponsors, federal agencies, or specially designated review groups.',
#  15603: 'Identify protocol problems, inform investigators of problems, or assist in problem resolution efforts, such as protocol revisions.',
#  15595: 'Prepare study-related documentation, such as protocol worksheets, procedural manuals, adverse event reports, institutional review board documents, or progress reports.',
#  15592: 'Track enrollment status of subjects and document dropout information such as dropout causes and subject contact efforts.',
#  15593: 'Review proposed study protocols to evaluate factors such as sample collection processes, data management plans, or potential subject risks.',
#  15609: 'Code, evaluate, or interpret collected study data.',
#  15586: 'Participate in preparation and management of research budgets and monetary disbursements.',
#  15596: 'Participate in the development of study protocols including guidelines for administration or data collection procedures.',
#  15601: 'Instruct research staff in scientific and procedural aspects of studies including standards of care, informed consent procedures, or documentation procedures.',
#  15607: 'Communicate with laboratories or investigators regarding laboratory findings.',
#  15583: 'Review scientific literature, participate in continuing education activities, or attend conferences and seminars to maintain current knowledge of clinical studies affairs and issues.',
#  15598: 'Order drugs or devices necessary for study completion.',
#  15591: 'Confer with health care professionals to determine the best recruitment practices for studies.',
#  15608: 'Collaborate with investigators to prepare presentations or reports of clinical study procedures, results, and conclusions.',
#  15612: 'Schedule subjects for appointments, procedures, or inpatient stays as required by study protocols.',
#  15587: 'Perform specific protocol procedures such as interviewing subjects, taking vital signs, and performing electrocardiograms.',
#  15604: 'Dispense medical devices or drugs, and calculate dosages and provide instructions as necessary.',
#  15600: 'Maintain contact with sponsors to schedule and coordinate site visits or to answer questions about issues such as incomplete data.',
#  15602: 'Inform patients or caregivers about study aspects and outcomes to be expected.',
#  15605: 'Direct the requisition, collection, labeling, storage, or shipment of specimens.',
#  15584: 'Register protocol patients with appropriate statistical centers as required.',
#  15588: 'Interpret protocols and advise treating physicians on appropriate dosage modifications or treatment calculations based on patient characteristics.',
#  15611: 'Arrange for research study sites and determine staff or equipment availability.',
#  15606: 'Contact outside health care providers and communicate with subjects to obtain follow-up information.',
#  15590: 'Contact industry representatives to ensure equipment and software specifications necessary for successful study completion.',
#  15582: 'Solicit industry-sponsored trials through contacts and professional organizations.',
#  15599: 'Organize space for study equipment and supplies.',
#  15589: 'Develop advertising and other informational materials to be used in subject recruitment.',
#  15618: 'Perform hydrologic, hydraulic, or water quality modeling.',
#  15631: 'Conduct, or oversee the conduct of, investigations on matters such as water storage, wastewater discharge, pollutants, permits, or other compliance and regulatory issues.',
#  15628: 'Develop plans to protect watershed health or rehabilitate watersheds.',
#  15634: 'Develop strategies for watershed operations to meet water supply and conservation goals or to ensure regulatory compliance with clean water laws or regulations.',
#  15627: 'Identify and characterize specific causes or sources of water pollution.',
#  15621: 'Write proposals, project reports, informational brochures, or other documents on wastewater purification, water supply and demand, or other water resource subjects.',
#  15624: 'Present water resource proposals to government, public interest groups, or community groups.',
#  15616: 'Review or evaluate designs for water detention facilities, storm drains, flood control facilities, or other hydraulic structures.',
#  15635: 'Conduct, or oversee the conduct of, chemical, physical, and biological water quality monitoring or sampling to ensure compliance with water quality standards.',
#  15630: 'Conduct technical studies for water resources on topics such as pollutants and water treatment options.',
#  15622: 'Recommend new or revised policies, procedures, or regulations to support water resource or conservation goals.',
#  15626: 'Monitor water use, demand, or quality in a particular geographic area.',
#  15633: 'Analyze storm water systems to identify opportunities for water resource improvements.',
#  15623: 'Provide technical expertise to assist communities in the development or implementation of storm water monitoring or other water programs.',
#  15619: 'Compile water resource data, using geographic information systems (GIS) or global position systems (GPS) software.',
#  15632: 'Conduct cost-benefit studies for watershed improvement projects or water management alternatives.',
#  ...}

# %%
# This cell takes ~2 min to run

# Take only the columns "Task ID" and "DWA ID" from the task_to_dwa pd.DataFrame then replace the Task IDs with the task text 
task_to_gwa = task_to_dwa[['Task ID', 'DWA ID']].replace(task_dict)
# then parse the DWA ID into the GWA IDs
task_to_gwa['DWA ID'] = task_to_gwa.apply(lambda row: row['DWA ID'][:9], axis = 1)
# then replace the GWA IDs with the GWA text    [.replace(gwa_dict)]
task_to_gwa = task_to_gwa.replace(gwa_dict)
task_to_gwa.head()
# Out:
#                                              Task ID  \
# 0  Review and analyze legislation, laws, or publi...
# 1  Review and analyze legislation, laws, or publi...
# 2  Direct or coordinate an organization's financi...
# 3  Confer with board members, organization offici...
# 4  Analyze operations to evaluate performance of ...
#
#                                               DWA ID
# 0                      Analyzing Data or Information
# 1          Provide Consultation and Advice to Others
# 2    Guiding, Directing, and Motivating Subordinates
# 3  Communicating with Supervisors, Peers, or Subo...
# 4                      Analyzing Data or Information

# %%
task_to_gwa.columns = ['Task', 'GWA'] # rename the column headers
task_to_gwa = task_to_gwa.drop_duplicates() # drop identical rows
task_to_gwa.to_csv('onet_tasks_gwas.csv', sep = ',', index = False) # write to csv

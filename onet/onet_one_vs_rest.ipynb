# %% [markdown]
# # Exploring One-Vs-Rest Techniques
#
# The purpose of this notebook is to explore using one-vs-rest as a technique to address the multi-label classification part of our project.
#
# **Last Updated**: Wednesday July 24, 2019
# <br> **Author**: Rebecca Hu

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('onet_tasks_gwas.csv')

# %% [markdown]
# Here is the pre-processing step.

# %%
#Remove punctuation & stopwords, use stemming to remove inflections, calculate TF-IDF matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english", ignore_stopwords=True)
analyzer = TfidfVectorizer(lowercase = True, stop_words = 'english', ngram_range = (1, 3)).build_analyzer() 

def stemmed_words(doc):
    return (stemmer.stem(w) for w in analyzer(doc))

# %% [markdown]
# Here is the model we'll be using, a simple linear regression.

# %%
#Logit pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

logit_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(analyzer=stemmed_words)),
    ('logit', LogisticRegression())])

# %% [markdown]
# ### OneVsRest Scikit-Learn
#
# ---
#
# First we'll try to use sk-learn's OneVsRestClassifier since its already pre-made.

# %%
#transform data to have one column for each unique class bc this is what the sklearn function requires
from sklearn.model_selection import train_test_split

y_dict = {}
for c in df.GWA.unique():
    labels = df.GWA.apply(lambda x: 1 if x == c else 0)
    y_dict[c] = labels
    
skdf = pd.concat([df,pd.DataFrame(y_dict)], axis = 1)

classes = skdf.GWA.unique()
train, test = train_test_split(skdf, test_size=0.33, shuffle=True)
X_train = train.Task
X_test = test.Task

# %%
# Define a pipeline combining a text feature extractor with multi lable classifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score

lr_pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(analyzer=stemmed_words)),
                ('clf', OneVsRestClassifier(LogisticRegression())),
            ])

for c in classes:
    print('... Processing {}'.format(c))
    # train the model using X_dtm & y
    lr_pipeline.fit(X_train, train[c])
    # compute the testing accuracy
    prediction = lr_pipeline.predict(X_test)
    print('Test accuracy is {}'.format(accuracy_score(test[c], prediction)))
# Out:
# ... Processing Analyzing Data or Information
# Test accuracy is 0.9674857656577764
# ... Processing Provide Consultation and Advice to Others
# Test accuracy is 0.9709319748276896
# ... Processing Guiding, Directing, and Motivating Subordinates
# Test accuracy is 0.948157027270003
# ... Processing Communicating with Supervisors, Peers, or Subordinates
# Test accuracy is 0.9565477974228349
# ... Processing Making Decisions and Solving Problems
# Test accuracy is 0.968684447108181
# ... Processing Developing Objectives and Strategies
# Test accuracy is 0.9862151633203476
# ... Processing Resolving Conflicts and Negotiating with Others
# Test accuracy is 0.9926580761162721
# ... Processing Documenting/Recording Information
# Test accuracy is 0.9484566976326041
# ... Processing Communicating with Persons Outside Organization
# Test accuracy is 0.9875636799520527
# ... Processing Interpreting the Meaning of Information for Others
# Test accuracy is 0.9845669763260414
# ... Processing Selling or Influencing Others
# Test accuracy is 0.989211866946359
# ... Processing Identifying Objects, Actions, and Events
# Test accuracy is 0.9941564279292778
# ... Processing Judging the Qualities of Things, Services, or People
# Test accuracy is 0.9796224153431226
# ... Processing Scheduling Work and Activities
# Test accuracy is 0.9941564279292778
# ... Processing Evaluating Information to Determine Compliance with Standards
# Test accuracy is 0.992358405753671
# ... Processing Thinking Creatively
# Test accuracy is 0.9403655978423734
# ... Processing Getting Information
# Test accuracy is 0.9581959844171412
# ... Processing Monitor Processes, Materials, or Surroundings
# Test accuracy is 0.9698831285585856
# ... Processing Training and Teaching Others
# Test accuracy is 0.9760263709919089
# ... Processing Staffing Organizational Units
# Test accuracy is 0.9959544501048846
# ... Processing Updating and Using Relevant Knowledge
# Test accuracy is 0.9911597243032664
# ... Processing Performing for or Working Directly with the Public
# Test accuracy is 0.9946059334731795
# ... Processing Establishing and Maintaining Interpersonal Relationships
# Test accuracy is 0.9977524722804915
# ... Processing Coaching and Developing Others
# Test accuracy is 0.9980521426430926
# ... Processing Processing Information
# Test accuracy is 0.9866646688642493
# ... Processing Monitoring and Controlling Resources
# Test accuracy is 0.9799220857057237
# ... Processing Inspecting Equipment, Structures, or Material
# Test accuracy is 0.9602936769553491
# ... Processing Repairing and Maintaining Mechanical Equipment
# Test accuracy is 0.9695834581959845
# ... Processing Controlling Machines and Processes
# Test accuracy is 0.9640395564878633
# ... Processing Performing General Physical Activities
# Test accuracy is 0.948157027270003
# ... Processing Estimating the Quantifiable Characteristics of Products, Events, or Information
# Test accuracy is 0.9832184596943362
# ... Processing Performing Administrative Activities
# Test accuracy is 0.9853161522325442
# ... Processing Interacting With Computers
# Test accuracy is 0.9880131854959544
# ... Processing Organizing, Planning, and Prioritizing Work
# Test accuracy is 0.9946059334731795
# ... Processing Handling and Moving Objects
# Test accuracy is 0.9054540005993408
# ... Processing Assisting and Caring for Others
# Test accuracy is 0.9704824692837878
# ... Processing Operating Vehicles, Mechanized Devices, or Equipment
# Test accuracy is 0.9931075816601738

# %% [markdown]
# On first glance, it looks like the sk-learn implementation of one-vs-rest is doing very well. But, remember that this implementation doesn't use any sampling methods and our data is highly imbalanced. So it is likely that although the accuracy is high, the model is probably just predicting the "rest" class instead of the target class for everything. In other words, there are many true negative, but also no true positives.
#
# So next, lets try to implement some sampling techniques that will balance our data. We'll over-sample the target class and under-sample the "rest" classes to create a training set that is more even split between the target class and the "rest". then, train on this new even dataset. First, lets try with a target class that is the label for a large proportion of the dataset: Handling and Moving Objects.
#
# <b> NOTE (08/06/2019) </b> : This sampling method I performed here was before I realized I needed to reformat the data before sampling. This method allows some of the same tasks to leak appear in the training and test sets, but they are labeled with different GWAs. The sampling method used in the final classifier fixes this problem by reformatting the data into "easy-to-read" and "one-hotted" dataframe. See the task_classification_helper_functions.py for the code for these functions. The code below gives a general idea of the sampling method I ended up using, but isn't implemented correctly.
#
# ---
#
# ### Target Class: Handling and Moving Objects

# %%
# baseline preprocessing + sampling
from sklearn.metrics import precision_recall_fscore_support

hamo_sample = df[df['GWA'] == 'Handling and Moving Objects'].sample(2000)
nonhamo_df = df[df['GWA'] != 'Handling and Moving Objects'].sample(3000)
nonhamo_df['GWA'] = ['Not Handling and Moving Objects'] * 3000
equal_hamo_data = pd.concat([hamo_sample, nonhamo_df])
X_train, X_test, y_train, y_test = train_test_split(equal_hamo_data['Task'], 
                                                    equal_hamo_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

# %%
# fit the model and make predictions
logit_pipe.fit(X_train, y_train)

train_predicted = logit_pipe.predict(X_train)
test_predicted = logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())

# %%
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)
#results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
#results[results['Actual'] != results['Predicted']].head(10)
# Out:
# Training Error:  0.059
# Precision:  [0.93673616 0.94877765]
# Recall:  [0.96733482 0.90254707]
# F1-Score:  [0.95178963 0.92508513]
# **********************************************************
# Test Error:  0.15
# Precision:  [0.87138264 0.81481481]
# Recall:  [0.88562092 0.79381443]
# F1-Score:  [0.87844408 0.80417755]

# %% [markdown]
# We still get a relatively high accuracy using the sampling technique and we can be more confident that our model is truly differentiating between the target class and other labels.
#
# ---
#
# Let's compare this to when we pre-process differently just to get an idea of what's working well.

# %%
# pre-processing without stemming + sampling

nonstem_logit_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase = True, stop_words = 'english', ngram_range = (1, 3))),
    ('logit', LogisticRegression())])

nonstem_logit_pipe.fit(X_train, y_train)

train_predicted = nonstem_logit_pipe.predict(X_train)
test_predicted = nonstem_logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']].head(10)
# Out:
# Training Error:  0.043
# Precision:  [0.94150299 0.97405005]
# Recall:  [0.9752322  0.93881197]
# F1-Score:  [0.95807082 0.95610644]
# **********************************************************
# Test Error:  0.156
# Precision:  [0.81568627 0.87346939]
# Recall:  [0.87029289 0.81992337]
# F1-Score:  [0.84210526 0.8458498 ]
#                                                     Task  \
# 14022  Track animals by checking for signs such as dr...
# 4807   Adjust or maintain equipment, such as lasers, ...
# 11753             Perform embalming duties as necessary.
# 11511  Train horses or other equines for riding, harn...
# 15050  Measure and mark locations for installation of...
# 18334  Operate auxiliary equipment and control multip...
# 14374  Dig ditches or trenches, backfill excavations,...
# 11784             Order, display, and maintain supplies.
# 16268  Dismantle machinery and equipment for shipment...
# 13786  Assign to workers duties such as trees to be c...
#
#                                 Actual                        Predicted
# 14022      Handling and Moving Objects  Not Handling and Moving Objects
# 4807       Handling and Moving Objects  Not Handling and Moving Objects
# 11753      Handling and Moving Objects  Not Handling and Moving Objects
# 11511      Handling and Moving Objects  Not Handling and Moving Objects
# 15050  Not Handling and Moving Objects      Handling and Moving Objects
# 18334  Not Handling and Moving Objects      Handling and Moving Objects
# 14374  Not Handling and Moving Objects      Handling and Moving Objects
# 11784      Handling and Moving Objects  Not Handling and Moving Objects
# 16268      Handling and Moving Objects  Not Handling and Moving Objects
# 13786  Not Handling and Moving Objects      Handling and Moving Objects

# %%
# baseline preprocessing, no sampling

hamo_sample = df[df['GWA'] == 'Handling and Moving Objects']
nonhamo_df = df[df['GWA'] != 'Handling and Moving Objects']
nonhamo_df['GWA'] = ['Not Handling and Moving Objects'] * nonhamo_df.shape[0]
equal_hamo_data = pd.concat([hamo_sample, nonhamo_df])
X_train, X_test, y_train, y_test = train_test_split(equal_hamo_data['Task'], 
                                                    equal_hamo_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

logit_pipe.fit(X_train, y_train)

train_predicted = logit_pipe.predict(X_train)
test_predicted = logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# Training Error:  0.09
# Precision:  [0.90925947 0.92781316]
# Recall:  [0.99568528 0.35819672]
# F1-Score:  [0.95051184 0.51685393]
# **********************************************************
# Test Error:  0.094
# Precision:  [0.92340653 0.69871795]
# Recall:  [0.97346132 0.43253968]
# F1-Score:  [0.9477735  0.53431373]
#                                                     Task  \
# 15997  Repair holes in tire tubes, using scrapers and...
# 18047  Stretch webbing and fabric, using webbing stre...
# 16553  Repair and adjust safes, vault doors, and vaul...
# 15733  Fill small dents that cannot be worked out wit...
# 7953   Select and assemble equipment and required bac...
# 15236  Start, stop, and control drilling speed of mac...
# 20093  Adjust controls to guide, position, or move eq...
# 14259  Form a smooth foundation by stapling plywood o...
# 12093  Perform work activities of subordinates, such ...
# 17316  Position cores into lower sections of molds, a...
# 15153  Prepare and apply weather-stripping, glazing, ...
# 13404  Record number and types of articles marked and...
# 16083  Disassemble and repair mechanical control devi...
# 18681  Disassemble defective parts or components, suc...
# 14418                    Set up and tear down equipment.
# 13949  Trap and destroy pests, such as moles, gophers...
# 14281  Apply mortar to tile back, position the tile, ...
# 17570  Adjust controls to set temperatures of coating...
# 14384  Smooth or finish freshly poured cement or conc...
# 15602  Repair or adjust equipment, machines, or defec...
# 15029  Process e-waste, such as computer components c...
# 11175                   Fill beverage or ice dispensers.
# 14564  Grind or polish glass, smoothing edges when ne...
# 18775  Peen edges of scratches or holes to repair def...
# 11935  Set up camps, and prepare meals for tour group...
# 17600  Remove excess materials or impurities from obj...
# 16805  Package finished products and prepare them for...
# 13954  Apply pesticides, herbicides or fertilizers to...
# 9629   Collect samples, such as blood, urine, or sput...
# 17216  Lay out, measure, and mark metal stock to disp...
# ...                                                  ...
# 15428  Repair, adjust, or replace electrical or mecha...
# 16679  Set up or operate machines or systems to crimp...
# 18257  Adjust controls and/or valves on equipment to ...
# 18290  Draw samples of products and conduct quality c...
# 14403  Spray materials, such as water, sand, steam, v...
# 17489  Correct problems by adjusting controls or by s...
# 16380  Repair cracks in wood or metal instruments, us...
# 10969  Stock, organize, and clean kitchens and cookin...
# 20061  Hook tow trucks to trailer hitches and fasten ...
# 15273  Mark patterns, locations, and depths of charge...
# 18688  Clean and polish metal items and jewelry piece...
# 16819  Disassemble timepieces such as watches, clocks...
# 18193  Adjust controls to position rod and to regulat...
# 9827   Prepare or calibrate equipment used to collect...
# 15075  Turn wheels of machines, using lever controls,...
# 11006  Grill, cook, and fry foods such as french frie...
# 7980   Adjust positions and controls of cameras, prin...
# 15208         Plug observation wells, and restore sites.
# 16568  Locate and repair frayed wiring, broken connec...
# 18826  Mix pigments to match patients' skin coloring,...
# 10134  Make preliminary impressions for study casts a...
# 14864  Install handrails under the direction of a car...
# 16324  Lay underground cable directly in trenches or ...
# 18819  Lay out and mark dimensions of parts, using te...
# 13305  Put undelivered parcels away, retrieve them wh...
# 14470  Turn valves to control air or water output of ...
# 17597                       Preheat workpieces in ovens.
# 19173  Repair mold defects, such as cracks or broken ...
# 18827     Adjust lenses and frames to correct alignment.
# 11033  Prepare and serve a variety of beverages such ...
#
#                                 Actual                        Predicted
# 15997  Not Handling and Moving Objects      Handling and Moving Objects
# 18047      Handling and Moving Objects  Not Handling and Moving Objects
# 16553  Not Handling and Moving Objects      Handling and Moving Objects
# 15733      Handling and Moving Objects  Not Handling and Moving Objects
# 7953       Handling and Moving Objects  Not Handling and Moving Objects
# 15236  Not Handling and Moving Objects      Handling and Moving Objects
# 20093  Not Handling and Moving Objects      Handling and Moving Objects
# 14259      Handling and Moving Objects  Not Handling and Moving Objects
# 12093      Handling and Moving Objects  Not Handling and Moving Objects
# 17316  Not Handling and Moving Objects      Handling and Moving Objects
# 15153      Handling and Moving Objects  Not Handling and Moving Objects
# 13404      Handling and Moving Objects  Not Handling and Moving Objects
# 16083  Not Handling and Moving Objects      Handling and Moving Objects
# 18681      Handling and Moving Objects  Not Handling and Moving Objects
# 14418      Handling and Moving Objects  Not Handling and Moving Objects
# 13949      Handling and Moving Objects  Not Handling and Moving Objects
# 14281      Handling and Moving Objects  Not Handling and Moving Objects
# 17570  Not Handling and Moving Objects      Handling and Moving Objects
# 14384  Not Handling and Moving Objects      Handling and Moving Objects
# 15602      Handling and Moving Objects  Not Handling and Moving Objects
# 15029      Handling and Moving Objects  Not Handling and Moving Objects
# 11175      Handling and Moving Objects  Not Handling and Moving Objects
# 14564      Handling and Moving Objects  Not Handling and Moving Objects
# 18775      Handling and Moving Objects  Not Handling and Moving Objects
# 11935      Handling and Moving Objects  Not Handling and Moving Objects
# 17600      Handling and Moving Objects  Not Handling and Moving Objects
# 16805      Handling and Moving Objects  Not Handling and Moving Objects
# 13954      Handling and Moving Objects  Not Handling and Moving Objects
# 9629       Handling and Moving Objects  Not Handling and Moving Objects
# 17216      Handling and Moving Objects  Not Handling and Moving Objects
# ...                                ...                              ...
# 15428  Not Handling and Moving Objects      Handling and Moving Objects
# 16679  Not Handling and Moving Objects      Handling and Moving Objects
# 18257      Handling and Moving Objects  Not Handling and Moving Objects
# 18290      Handling and Moving Objects  Not Handling and Moving Objects
# 14403      Handling and Moving Objects  Not Handling and Moving Objects
# 17489      Handling and Moving Objects  Not Handling and Moving Objects
# 16380      Handling and Moving Objects  Not Handling and Moving Objects
# 10969      Handling and Moving Objects  Not Handling and Moving Objects
# 20061      Handling and Moving Objects  Not Handling and Moving Objects
# 15273      Handling and Moving Objects  Not Handling and Moving Objects
# 18688      Handling and Moving Objects  Not Handling and Moving Objects
# 16819      Handling and Moving Objects  Not Handling and Moving Objects
# 18193  Not Handling and Moving Objects      Handling and Moving Objects
# 9827       Handling and Moving Objects  Not Handling and Moving Objects
# 15075  Not Handling and Moving Objects      Handling and Moving Objects
# 11006      Handling and Moving Objects  Not Handling and Moving Objects
# 7980       Handling and Moving Objects  Not Handling and Moving Objects
# 15208      Handling and Moving Objects  Not Handling and Moving Objects
# 16568  Not Handling and Moving Objects      Handling and Moving Objects
# 18826      Handling and Moving Objects  Not Handling and Moving Objects
# 10134      Handling and Moving Objects  Not Handling and Moving Objects
# 14864      Handling and Moving Objects  Not Handling and Moving Objects
# 16324      Handling and Moving Objects  Not Handling and Moving Objects
# 18819      Handling and Moving Objects  Not Handling and Moving Objects
# 13305      Handling and Moving Objects  Not Handling and Moving Objects
# 14470  Not Handling and Moving Objects      Handling and Moving Objects
# 17597      Handling and Moving Objects  Not Handling and Moving Objects
# 19173  Not Handling and Moving Objects      Handling and Moving Objects
# 18827  Not Handling and Moving Objects      Handling and Moving Objects
# 11033      Handling and Moving Objects  Not Handling and Moving Objects
#
# [190 rows x 3 columns]

# %%
# no stemming, no sampling 
nonstem_logit_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase = True, stop_words = 'english', ngram_range = (1, 3))),
    ('logit', LogisticRegression())])

hamo_sample = df[df['GWA'] == 'Handling and Moving Objects']
nonhamo_df = df[df['GWA'] != 'Handling and Moving Objects']
nonhamo_df['GWA'] = ['Not Handling and Moving Objects'] * nonhamo_df.shape[0]
equal_hamo_data = pd.concat([hamo_sample, nonhamo_df])
X_train, X_test, y_train, y_test = train_test_split(equal_hamo_data['Task'], 
                                                    equal_hamo_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

nonstem_logit_pipe.fit(X_train, y_train)

train_predicted = nonstem_logit_pipe.predict(X_train)
test_predicted = nonstem_logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results#[results['Actual'] != results['Predicted']].head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Training Error:  0.097
# Precision:  [0.90186835 0.93291925]
# Recall:  [0.99656969 0.30553295]
# F1-Score:  [0.94685699 0.4603126 ]
# **********************************************************
# Test Error:  0.087
# Precision:  [0.9287613  0.70422535]
# Recall:  [0.9765232  0.42735043]
# F1-Score:  [0.9520436  0.53191489]
#                                                     Task  \
# 8171   Order, perform, and interpret tests and analyz...
# 8588   Provide training and supervision in therapy te...
# 6595   Develop and use multimedia course materials an...
# 4182   Identify, procure, or develop test equipment, ...
# 15187  Push levers and brake pedals to control gasoli...
# 9484   Order, label, and count stock of medications, ...
# 15137  Install solar thermal system controllers and s...
# 20058  Weigh materials or products and record weight ...
# 19493        Maintain knowledge of first-aid procedures.
# 5303   Recommend materials for reliable performance i...
# 13889  Prepare containers of semen for freezing and s...
# 12433  Set up and arrange displays or demonstration a...
# 15236  Start, stop, and control drilling speed of mac...
# 15673  Test and repair circuits and sensors, followin...
# 13172  Announce arrival and departure information, us...
# 3079   Confer with biologists or other researchers in...
# 9197   Harvest cell cultures at optimum time, based o...
# 1468   Supervise employees or subcontractors to ensur...
# 19940  Respond to passengers' questions, requests, or...
# 18901  Disassemble, clean, and reassemble sprayers or...
# 6575   Review papers or serve on editorial boards for...
# 18834  Examine prescriptions, work orders, or broken ...
# 11709  Direct casket and floral display placement and...
# 15680                           Order replacement parts.
# 8569   Correct deformities by means of plaster casts ...
# 15266  Tie specified lengths of delaying fuses into p...
# 3610   Design, implement, maintain, or improve electr...
# 672                                        Graft plants.
# 13423  Sell materials, equipment, and other items fro...
# 17424  Analyze engineering drawings, blueprints, spec...
# ...                                                  ...
# 18523  Operate or tend machines to mix or blend any o...
# 41     Develop sustainability reports, presentations,...
# 1341           Select or direct the execution of trades.
# 2057   Identify opportunities to improve the operatio...
# 16339  Adjust cameras, photographic mechanisms, or eq...
# 4636   Select, calibrate, or operate equipment used i...
# 12996  Compute bills, collect payments, and make chan...
# 2289   Conduct financial analyses related to investme...
# 555    Plan or implement improvements to internal or ...
# 11298     Dust furniture, walls, machines, or equipment.
# 690    Prepare budgets or financial reports for farm ...
# 1558   Determine which products should be featured in...
# 11082                        Relay food orders to cooks.
# 4703   Modify, maintain, or repair electronics equipm...
# 1906   Develop or maintain models for logistics uses,...
# 2518    Supervise, train, or mentor junior team members.
# 3800   Investigate theoretical or conceptual issues, ...
# 7551   Select, acquire, store, and issue equipment an...
# 18718  Assemble and secure mold sections used to cast...
# 12313                      Monitor markets or positions.
# 13917  Drive trucks to haul crops, supplies, tools, o...
# 15591  Measure, cut, and install frameworks and condu...
# 1761   Review material and labor requirements to deci...
# 5102   Instruct undergraduate and graduate students w...
# 3846   Maintain and coordinate repair of marine machi...
# 1986   Negotiate collective agreements on behalf of e...
# 4998   Develop and maintain liaisons and effective wo...
# 10338  Provide emergency medical services as required...
# 9180   Operate, calibrate, or maintain equipment used...
# 6645   Prepare and deliver lectures to undergraduate ...
#
#                                 Actual                        Predicted
# 8171   Not Handling and Moving Objects  Not Handling and Moving Objects
# 8588   Not Handling and Moving Objects  Not Handling and Moving Objects
# 6595   Not Handling and Moving Objects  Not Handling and Moving Objects
# 4182   Not Handling and Moving Objects  Not Handling and Moving Objects
# 15187  Not Handling and Moving Objects  Not Handling and Moving Objects
# 9484   Not Handling and Moving Objects  Not Handling and Moving Objects
# 15137      Handling and Moving Objects      Handling and Moving Objects
# 20058  Not Handling and Moving Objects  Not Handling and Moving Objects
# 19493  Not Handling and Moving Objects  Not Handling and Moving Objects
# 5303   Not Handling and Moving Objects  Not Handling and Moving Objects
# 13889      Handling and Moving Objects  Not Handling and Moving Objects
# 12433      Handling and Moving Objects  Not Handling and Moving Objects
# 15236  Not Handling and Moving Objects  Not Handling and Moving Objects
# 15673  Not Handling and Moving Objects  Not Handling and Moving Objects
# 13172  Not Handling and Moving Objects  Not Handling and Moving Objects
# 3079   Not Handling and Moving Objects  Not Handling and Moving Objects
# 9197       Handling and Moving Objects  Not Handling and Moving Objects
# 1468   Not Handling and Moving Objects  Not Handling and Moving Objects
# 19940  Not Handling and Moving Objects  Not Handling and Moving Objects
# 18901      Handling and Moving Objects  Not Handling and Moving Objects
# 6575   Not Handling and Moving Objects  Not Handling and Moving Objects
# 18834  Not Handling and Moving Objects  Not Handling and Moving Objects
# 11709  Not Handling and Moving Objects  Not Handling and Moving Objects
# 15680  Not Handling and Moving Objects  Not Handling and Moving Objects
# 8569   Not Handling and Moving Objects  Not Handling and Moving Objects
# 15266      Handling and Moving Objects  Not Handling and Moving Objects
# 3610   Not Handling and Moving Objects  Not Handling and Moving Objects
# 672    Not Handling and Moving Objects  Not Handling and Moving Objects
# 13423  Not Handling and Moving Objects  Not Handling and Moving Objects
# 17424  Not Handling and Moving Objects  Not Handling and Moving Objects
# ...                                ...                              ...
# 18523  Not Handling and Moving Objects  Not Handling and Moving Objects
# 41     Not Handling and Moving Objects  Not Handling and Moving Objects
# 1341   Not Handling and Moving Objects  Not Handling and Moving Objects
# 2057   Not Handling and Moving Objects  Not Handling and Moving Objects
# 16339      Handling and Moving Objects      Handling and Moving Objects
# 4636       Handling and Moving Objects  Not Handling and Moving Objects
# 12996  Not Handling and Moving Objects  Not Handling and Moving Objects
# 2289   Not Handling and Moving Objects  Not Handling and Moving Objects
# 555    Not Handling and Moving Objects  Not Handling and Moving Objects
# 11298  Not Handling and Moving Objects  Not Handling and Moving Objects
# 690    Not Handling and Moving Objects  Not Handling and Moving Objects
# 1558   Not Handling and Moving Objects  Not Handling and Moving Objects
# 11082  Not Handling and Moving Objects  Not Handling and Moving Objects
# 4703   Not Handling and Moving Objects  Not Handling and Moving Objects
# 1906   Not Handling and Moving Objects  Not Handling and Moving Objects
# 2518   Not Handling and Moving Objects  Not Handling and Moving Objects
# 3800   Not Handling and Moving Objects  Not Handling and Moving Objects
# 7551   Not Handling and Moving Objects  Not Handling and Moving Objects
# 18718      Handling and Moving Objects      Handling and Moving Objects
# 12313  Not Handling and Moving Objects  Not Handling and Moving Objects
# 13917  Not Handling and Moving Objects  Not Handling and Moving Objects
# 15591      Handling and Moving Objects      Handling and Moving Objects
# 1761   Not Handling and Moving Objects  Not Handling and Moving Objects
# 5102   Not Handling and Moving Objects  Not Handling and Moving Objects
# 3846   Not Handling and Moving Objects  Not Handling and Moving Objects
# 1986   Not Handling and Moving Objects  Not Handling and Moving Objects
# 4998   Not Handling and Moving Objects  Not Handling and Moving Objects
# 10338  Not Handling and Moving Objects  Not Handling and Moving Objects
# 9180   Not Handling and Moving Objects  Not Handling and Moving Objects
# 6645   Not Handling and Moving Objects  Not Handling and Moving Objects
#
# [2023 rows x 3 columns]

# %% [markdown]
# What we see with the experiments without sampling is that the resulting error is always around 10%, the "Handling and Moving Objects" class is approximately 10% of the data so we have the same problem we had before where the model is likely just commonly predicting True Negatives (it just keeps predicting "Not Handling and Moving Obejcts"), but rarely getting a True Positive and instead getting many False Negatives, as illustrated in the pd.DataFrame above.
#
# Now let's try the one-vs-rest approach with a smaller class.
#
# ---
#
# ### Target Class: Analyzing Data or Information

# %%
#baseline preprocessing + sampling
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support

adoi_sample = df[df['GWA'] == 'Analyzing Data or Information'].sample(600)
nonadoi_df = df[df['GWA'] != 'Analyzing Data or Information'].sample(600)
nonadoi_df['GWA'] = ['Not Analyzing Data or Information'] * 600
equal_adoi_data = pd.concat([adoi_sample, nonadoi_df])
X_train, X_test, y_train, y_test = train_test_split(equal_adoi_data['Task'], 
                                                    equal_adoi_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

logit_pipe.fit(X_train, y_train)

train_predicted = logit_pipe.predict(X_train)
test_predicted = logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']].head(10)
# Out:
# Training Error:  0.009
# Precision:  [0.98366606 0.99810964]
# Recall:  [0.99815838 0.98324022]
# F1-Score:  [0.99085923 0.99061914]
# **********************************************************
# Test Error:  0.233
# Precision:  [0.71641791 0.83018868]
# Recall:  [0.84210526 0.6984127 ]
# F1-Score:  [0.77419355 0.75862069]
#                                                     Task  \
# 4357   Calculate excavation tonnage and prepare graph...
# 521    Review invoices, work orders, consumption repo...
# 12293  Supply the latest price quotes on any security...
# 2892   Evaluate local area network (LAN) or wide area...
# 8437   Design or use surveillance tools, such as scre...
# 5415   Determine methods to incorporate geomethane or...
# 3066   Transfer or rescale information from original ...
# 8629   Review physician's referral and patient's medi...
# 5464   Evaluate research data in terms of its impact ...
# 7643   Study films or scripts to determine how musica...
#
#                                   Actual                          Predicted
# 4357       Analyzing Data or Information  Not Analyzing Data or Information
# 521        Analyzing Data or Information  Not Analyzing Data or Information
# 12293  Not Analyzing Data or Information      Analyzing Data or Information
# 2892   Not Analyzing Data or Information      Analyzing Data or Information
# 8437   Not Analyzing Data or Information      Analyzing Data or Information
# 5415   Not Analyzing Data or Information      Analyzing Data or Information
# 3066   Not Analyzing Data or Information      Analyzing Data or Information
# 8629       Analyzing Data or Information  Not Analyzing Data or Information
# 5464   Not Analyzing Data or Information      Analyzing Data or Information
# 7643   Not Analyzing Data or Information      Analyzing Data or Information

# %%
# pre-processing without stemming + sampling

nonstem_logit_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase = True, stop_words = 'english', ngram_range = (1, 3))),
    ('logit', LogisticRegression())])

adoi_sample = df[df['GWA'] == 'Analyzing Data or Information'].sample(600)
nonadoi_df = df[df['GWA'] != 'Analyzing Data or Information'].sample(600)
nonadoi_df['GWA'] = ['Not Analyzing Data or Information'] * 600
equal_adoi_data = pd.concat([adoi_sample, nonadoi_df])
X_train, X_test, y_train, y_test = train_test_split(equal_adoi_data['Task'], 
                                                    equal_adoi_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

nonstem_logit_pipe.fit(X_train, y_train)

train_predicted = nonstem_logit_pipe.predict(X_train)
test_predicted = nonstem_logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']].head(10)
# Out:
# Training Error:  0.006
# Precision:  [0.99626866 0.99264706]
# Recall:  [0.99256506 0.99630996]
# F1-Score:  [0.99441341 0.99447514]
# **********************************************************
# Test Error:  0.133
# Precision:  [0.88333333 0.85      ]
# Recall:  [0.85483871 0.87931034]
# F1-Score:  [0.86885246 0.86440678]
#                                                     Task  \
# 12360  Visit establishments to evaluate needs or to p...
# 11     Review reports submitted by staff members to r...
# 4113             Verify energy bills and meter readings.
# 9842   Perform tests to identify any potential hazard...
# 1820   Review employer practices or employee data to ...
# 16828  Bend inner coils of springs away from or towar...
# 1999   Observe, interview, and survey employees and c...
# 15976  Test and inspect engines to determine malfunct...
# 3457   Review existing standards, controls, or equipm...
# 3953                  Conduct automotive design reviews.
#
#                                   Actual                          Predicted
# 12360  Not Analyzing Data or Information      Analyzing Data or Information
# 11         Analyzing Data or Information  Not Analyzing Data or Information
# 4113       Analyzing Data or Information  Not Analyzing Data or Information
# 9842   Not Analyzing Data or Information      Analyzing Data or Information
# 1820   Not Analyzing Data or Information      Analyzing Data or Information
# 16828  Not Analyzing Data or Information      Analyzing Data or Information
# 1999       Analyzing Data or Information  Not Analyzing Data or Information
# 15976  Not Analyzing Data or Information      Analyzing Data or Information
# 3457       Analyzing Data or Information  Not Analyzing Data or Information
# 3953       Analyzing Data or Information  Not Analyzing Data or Information

# %%
# baseline preprocessing, no sampling

adoi_sample = df[df['GWA'] == 'Analyzing Data or Information']
nonadoi_df = df[df['GWA'] != 'Analyzing Data or Information']
nonadoi_df['GWA'] = ['Not Analyzing Data or Information'] * nonadoi_df.shape[0]
equal_adoi_data = pd.concat([adoi_sample, nonadoi_df])
X_train, X_test, y_train, y_test = train_test_split(equal_adoi_data['Task'], 
                                                    equal_adoi_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

logit_pipe.fit(X_train, y_train)

train_predicted = logit_pipe.predict(X_train)
test_predicted = logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# Training Error:  0.032
# Precision:  [0.96826881 1.        ]
# Recall:  [1.         0.02698145]
# F1-Score:  [0.98387863 0.05254516]
# **********************************************************
# Test Error:  0.034
# Precision:  [0.9681592  0.61538462]
# Recall:  [0.99743721 0.11111111]
# F1-Score:  [0.98258016 0.18823529]
#                                                     Task  \
# 4698   Assemble or analyze electronics technologies t...
# 2122   Analyze impact on, and risk to, essential busi...
# 9255   Identify tissue structures or cell components ...
# 135    Analyze the effectiveness of marketing tactics...
# 4717   Collect and analyze data related to quality or...
# 5065   Collect and dissect animal specimens and exami...
# 277                           Perform tax planning work.
# 1859   Review contractual commitments, customer speci...
# 2337   Examine documents to determine degree of risk ...
# 3990   Evaluate data to develop new mining products, ...
# 9145   Diagnose health conditions based on patients' ...
# 2530   Analyze financial or operational performance o...
# 3579   Check construction plans, design calculations,...
# 2513   Evaluate the risks related to green investment...
# 1121   Review proposed study protocols to evaluate fa...
# 5108   Compile and analyze molecular or cellular expe...
# 5974   Use chemicals or other substances to examine l...
# 5509   Write technical documents or academic articles...
# 6450   Apply relevant laws, regulations, policies, or...
# 270    Analyze the financial details of past, present...
# 1559   Monitor competitors' sales activities by follo...
# 3021   Check and analyze operating system or applicat...
# 3328   Write program code to analyze data using stati...
# 8117   Analyze test results and develop a treatment p...
# 13224  Arrange for transport, using a variety of mode...
# 379    Review logs, datasheets, or reports to ensure ...
# 4941   Analyze aerial photographs to detect and inter...
# 593    Analyze compensation policies, government regu...
# 12319  Track and analyze factors that affect price mo...
# 2507   Conduct statistical analyses to quantify risk,...
# ...                                                  ...
# 5522   Assess the costs and benefits of various activ...
# 5966   Collect impressions of dust from surfaces to o...
# 2785   Analyze equipment performance records to deter...
# 291    Review collection reports to determine the sta...
# 8372   Interpret imaging data and confer with other m...
# 1450   Identify potential for loss and develop strate...
# 573    Analyze all aspects of corporate logistics to ...
# 5313   Analyze data to determine validity, quality, a...
# 19870  Visit development or work sites to determine p...
# 1883   Provide logistical facility or capacity planni...
# 1542   Monitor consumer preferences or environmental ...
# 1507   Conduct quantitative risk assessments for huma...
# 2567   Conduct logical analyses of business, scientif...
# 2045   Measure energy usage with devices such as data...
# 5369   Collect and analyze data to determine environm...
# 13662  Determine manner in which mail is to be sent, ...
# 1906   Develop or maintain models for logistics uses,...
# 4855   Document or analyze fuel cell test data, using...
# 1988   Perform multifactor data and cost analyses tha...
# 8927   Evaluate patients' behavior to formulate diagn...
# 5816   Set up and conduct chemical experiments, tests...
# 8280   Evaluate patients to determine eligibility for...
# 13201  Select shipment routes, based on nature of goo...
# 5949   Examine and analyze material for presence and ...
# 2080   Perform risk analyses so that appropriate coun...
# 9915   Evaluate patients' laboratory and medical reco...
# 3283   Analyze information obtained from management t...
# 3997   Prepare technical reports of findings or recom...
# 9460   Conduct nutritional assessments of individuals...
# 19747  Determine geographical positions of ships, usi...
#
#                                   Actual                          Predicted
# 4698       Analyzing Data or Information  Not Analyzing Data or Information
# 2122       Analyzing Data or Information  Not Analyzing Data or Information
# 9255       Analyzing Data or Information  Not Analyzing Data or Information
# 135        Analyzing Data or Information  Not Analyzing Data or Information
# 4717       Analyzing Data or Information  Not Analyzing Data or Information
# 5065       Analyzing Data or Information  Not Analyzing Data or Information
# 277        Analyzing Data or Information  Not Analyzing Data or Information
# 1859       Analyzing Data or Information  Not Analyzing Data or Information
# 2337       Analyzing Data or Information  Not Analyzing Data or Information
# 3990       Analyzing Data or Information  Not Analyzing Data or Information
# 9145       Analyzing Data or Information  Not Analyzing Data or Information
# 2530       Analyzing Data or Information  Not Analyzing Data or Information
# 3579       Analyzing Data or Information  Not Analyzing Data or Information
# 2513       Analyzing Data or Information  Not Analyzing Data or Information
# 1121       Analyzing Data or Information  Not Analyzing Data or Information
# 5108       Analyzing Data or Information  Not Analyzing Data or Information
# 5974       Analyzing Data or Information  Not Analyzing Data or Information
# 5509       Analyzing Data or Information  Not Analyzing Data or Information
# 6450       Analyzing Data or Information  Not Analyzing Data or Information
# 270        Analyzing Data or Information  Not Analyzing Data or Information
# 1559       Analyzing Data or Information  Not Analyzing Data or Information
# 3021       Analyzing Data or Information  Not Analyzing Data or Information
# 3328   Not Analyzing Data or Information      Analyzing Data or Information
# 8117   Not Analyzing Data or Information      Analyzing Data or Information
# 13224      Analyzing Data or Information  Not Analyzing Data or Information
# 379        Analyzing Data or Information  Not Analyzing Data or Information
# 4941   Not Analyzing Data or Information      Analyzing Data or Information
# 593        Analyzing Data or Information  Not Analyzing Data or Information
# 12319      Analyzing Data or Information  Not Analyzing Data or Information
# 2507       Analyzing Data or Information  Not Analyzing Data or Information
# ...                                  ...                                ...
# 5522       Analyzing Data or Information  Not Analyzing Data or Information
# 5966       Analyzing Data or Information  Not Analyzing Data or Information
# 2785       Analyzing Data or Information  Not Analyzing Data or Information
# 291        Analyzing Data or Information  Not Analyzing Data or Information
# 8372       Analyzing Data or Information  Not Analyzing Data or Information
# 1450       Analyzing Data or Information  Not Analyzing Data or Information
# 573        Analyzing Data or Information  Not Analyzing Data or Information
# 5313   Not Analyzing Data or Information      Analyzing Data or Information
# 19870      Analyzing Data or Information  Not Analyzing Data or Information
# 1883       Analyzing Data or Information  Not Analyzing Data or Information
# 1542       Analyzing Data or Information  Not Analyzing Data or Information
# 1507       Analyzing Data or Information  Not Analyzing Data or Information
# 2567       Analyzing Data or Information  Not Analyzing Data or Information
# 2045       Analyzing Data or Information  Not Analyzing Data or Information
# 5369   Not Analyzing Data or Information      Analyzing Data or Information
# 13662      Analyzing Data or Information  Not Analyzing Data or Information
# 1906       Analyzing Data or Information  Not Analyzing Data or Information
# 4855       Analyzing Data or Information  Not Analyzing Data or Information
# 1988       Analyzing Data or Information  Not Analyzing Data or Information
# 8927       Analyzing Data or Information  Not Analyzing Data or Information
# 5816       Analyzing Data or Information  Not Analyzing Data or Information
# 8280       Analyzing Data or Information  Not Analyzing Data or Information
# 13201      Analyzing Data or Information  Not Analyzing Data or Information
# 5949       Analyzing Data or Information  Not Analyzing Data or Information
# 2080       Analyzing Data or Information  Not Analyzing Data or Information
# 9915       Analyzing Data or Information  Not Analyzing Data or Information
# 3283       Analyzing Data or Information  Not Analyzing Data or Information
# 3997       Analyzing Data or Information  Not Analyzing Data or Information
# 9460       Analyzing Data or Information  Not Analyzing Data or Information
# 19747      Analyzing Data or Information  Not Analyzing Data or Information
#
# [69 rows x 3 columns]

# %%
# no stemming, no sampling

nonstem_logit_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase = True, stop_words = 'english', ngram_range = (1, 3))),
    ('logit', LogisticRegression())])

adoi_sample = df[df['GWA'] == 'Analyzing Data or Information']
nonadoi_df = df[df['GWA'] != 'Analyzing Data or Information']
nonadoi_df['GWA'] = ['Not Analyzing Data or Information'] * nonadoi_df.shape[0]
equal_adoi_data = pd.concat([adoi_sample, nonadoi_df])
X_train, X_test, y_train, y_test = train_test_split(equal_adoi_data['Task'], 
                                                    equal_adoi_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

nonstem_logit_pipe.fit(X_train, y_train)

train_predicted = nonstem_logit_pipe.predict(X_train)
test_predicted = nonstem_logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']].head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# Training Error:  0.033
# Precision:  [0.96722754 0.92857143]
# Recall:  [0.99994315 0.02134647]
# F1-Score:  [0.9833133  0.04173355]
# **********************************************************
# Test Error:  0.024
# Precision:  [0.97665176 0.9       ]
# Recall:  [0.99949161 0.16071429]
# F1-Score:  [0.9879397  0.27272727]
#                                                     Task  \
# 9883   Determine or coordinate treatment plans by req...
# 8117   Analyze test results and develop a treatment p...
# 8464   Evaluate medical information to determine pati...
# 1917   Compare locations or environmental policies of...
# 3269   Apply mathematical theories and techniques to ...
# 4698   Assemble or analyze electronics technologies t...
# 1731   Identify relevant guidance documents, internat...
# 54     Review financial statements, sales or activity...
# 13201  Select shipment routes, based on nature of goo...
# 19870  Visit development or work sites to determine p...
#
#                                   Actual                          Predicted
# 9883       Analyzing Data or Information  Not Analyzing Data or Information
# 8117   Not Analyzing Data or Information      Analyzing Data or Information
# 8464       Analyzing Data or Information  Not Analyzing Data or Information
# 1917       Analyzing Data or Information  Not Analyzing Data or Information
# 3269       Analyzing Data or Information  Not Analyzing Data or Information
# 4698       Analyzing Data or Information  Not Analyzing Data or Information
# 1731       Analyzing Data or Information  Not Analyzing Data or Information
# 54         Analyzing Data or Information  Not Analyzing Data or Information
# 13201      Analyzing Data or Information  Not Analyzing Data or Information
# 19870      Analyzing Data or Information  Not Analyzing Data or Information

# %% [markdown]
# The sampling appears to still be effective for a target class that is a small proportion of the overall dataset.
# Let's continue to experiment on an even smaller target class.
#
# ---
#
# ### Target Class: Performing for or working Directly with the Public

# %%
#baseline preprocessing + sampling
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support

pwdwp_sample = df[df['GWA'] == 'Performing for or Working Directly with the Public'].sample(100)
nonpwdwp_df = df[df['GWA'] != 'Performing for or Working Directly with the Public'].sample(100)
nonpwdwp_df['GWA'] = ['Not PWDWP'] * 100
equal_pwdwp_data = pd.concat([pwdwp_sample, nonpwdwp_df])
X_train, X_test, y_train, y_test = train_test_split(equal_pwdwp_data['Task'], 
                                                    equal_pwdwp_data['GWA'], 
                                                    test_size = 0.15,
                                                    shuffle = True)

logit_pipe.fit(X_train, y_train)

train_predicted = logit_pipe.predict(X_train)
test_predicted = logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']].head(10)
# Out:
# Training Error:  0.0
# Precision:  [1. 1.]
# Recall:  [1. 1.]
# F1-Score:  [1. 1.]
# **********************************************************
# Test Error:  0.067
# Precision:  [0.86666667 1.        ]
# Recall:  [1.         0.88235294]
# F1-Score:  [0.92857143 0.9375    ]
#                                                    Task  \
# 7471  Create and approve storyboards in conjunction ...
# 7464  Consult with writers, producers, or actors abo...
#
#                                                  Actual  Predicted
# 7471  Performing for or Working Directly with the Pu...  Not PWDWP
# 7464  Performing for or Working Directly with the Pu...  Not PWDWP

# %%
#no stemming + sampling
nonstem_logit_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(lowercase = True, stop_words = 'english', ngram_range = (1, 3))),
    ('logit', LogisticRegression())])

pwdwp_sample = df[df['GWA'] == 'Performing for or Working Directly with the Public'].sample(100)
nonpwdwp_df = df[df['GWA'] != 'Performing for or Working Directly with the Public'].sample(100)
nonpwdwp_df['GWA'] = ['Not PWDWP'] * 100
equal_pwdwp_data = pd.concat([pwdwp_sample, nonpwdwp_df])
X_train, X_test, y_train, y_test = train_test_split(equal_pwdwp_data['Task'], 
                                                    equal_pwdwp_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

nonstem_logit_pipe.fit(X_train, y_train)

train_predicted = nonstem_logit_pipe.predict(X_train)
test_predicted = nonstem_logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results#[results['Actual'] != results['Predicted']].head(10)
# Out:
# Training Error:  0.0
# Precision:  [1. 1.]
# Recall:  [1. 1.]
# F1-Score:  [1. 1.]
# **********************************************************
# Test Error:  0.25
# Precision:  [0.54545455 1.        ]
# Recall:  [1.         0.64285714]
# F1-Score:  [0.70588235 0.7826087 ]
#                                                     Task  \
# 13143  Hear and resolve complaints from customers or ...
# 3883   Recommend design modifications to eliminate ma...
# 13382  Confer or correspond with establishment repres...
# 11673  Answer customer inquiries or explain cost, ava...
# 9642   Make appointments, keep records, or perform ot...
# 8862   Instruct individuals, families, or other group...
# 13689  Communicate with customers, employees, and oth...
# 16674  Fit and fasten sheet metal coverings to surfac...
# 12508  Contact utility companies for service hookups ...
# 8761   Explain treatment procedures to patients to ga...
# 6889   Provide interpretation and transcription of re...
# 16369  Contribute expertise to develop medical mainte...
# 17643  Mount negatives and plates in cameras, set exp...
# 7665            Play from memory or by following scores.
# 7577   Harmonize body movements to rhythm of musical ...
# 19355  Record in log books information such as flight...
# 10410  Create openings in buildings for ventilation o...
# 1015   Monitor staffing levels to ensure that games a...
# 5215   Monitor wildlife populations and assess the im...
# 10324  Discipline staff for violation of department r...
#
#                                                   Actual  \
# 13143  Performing for or Working Directly with the Pu...
# 3883                                           Not PWDWP
# 13382  Performing for or Working Directly with the Pu...
# 11673  Performing for or Working Directly with the Pu...
# 9642                                           Not PWDWP
# 8862                                           Not PWDWP
# 13689  Performing for or Working Directly with the Pu...
# 16674                                          Not PWDWP
# 12508                                          Not PWDWP
# 8761                                           Not PWDWP
# 6889                                           Not PWDWP
# 16369                                          Not PWDWP
# 17643                                          Not PWDWP
# 7665   Performing for or Working Directly with the Pu...
# 7577   Performing for or Working Directly with the Pu...
# 19355                                          Not PWDWP
# 10410                                          Not PWDWP
# 1015                                           Not PWDWP
# 5215                                           Not PWDWP
# 10324                                          Not PWDWP
#
#                                                Predicted
# 13143  Performing for or Working Directly with the Pu...
# 3883                                           Not PWDWP
# 13382  Performing for or Working Directly with the Pu...
# 11673  Performing for or Working Directly with the Pu...
# 9642   Performing for or Working Directly with the Pu...
# 8862   Performing for or Working Directly with the Pu...
# 13689  Performing for or Working Directly with the Pu...
# 16674                                          Not PWDWP
# 12508  Performing for or Working Directly with the Pu...
# 8761                                           Not PWDWP
# 6889   Performing for or Working Directly with the Pu...
# 16369                                          Not PWDWP
# 17643                                          Not PWDWP
# 7665   Performing for or Working Directly with the Pu...
# 7577   Performing for or Working Directly with the Pu...
# 19355                                          Not PWDWP
# 10410                                          Not PWDWP
# 1015   Performing for or Working Directly with the Pu...
# 5215                                           Not PWDWP
# 10324                                          Not PWDWP

# %%
#baseline preprocessing + no sampling
pwdwp_sample = df[df['GWA'] == 'Performing for or Working Directly with the Public']
nonpwdwp_df = df[df['GWA'] != 'Performing for or Working Directly with the Public']
nonpwdwp_df['GWA'] = ['Not PWDWP'] * nonpwdwp_df.shape[0]
equal_pwdwp_data = pd.concat([pwdwp_sample, nonpwdwp_df])
X_train, X_test, y_train, y_test = train_test_split(equal_pwdwp_data['Task'], 
                                                    equal_pwdwp_data['GWA'], 
                                                    test_size = 0.15,
                                                    shuffle = True)

logit_pipe.fit(X_train, y_train)

train_predicted = logit_pipe.predict(X_train)
test_predicted = logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']].head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# Training Error:  0.006
# Precision:  [0.99377509 0.        ]
# Recall:  [1. 0.]
# F1-Score:  [0.99687783 0.        ]
# **********************************************************
# Test Error:  0.01
# Precision:  [0.98978247 0.        ]
# Recall:  [1. 0.]
# F1-Score:  [0.994865 0.      ]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                                                     Task  \
# 12350  Answer customers' questions about products, pr...
# 12639  Answer customer questions regarding problems w...
# 7580   Coordinate dancing with that of partners or da...
# 11456  Answer patrons' questions about gaming machine...
# 11427  Monitor stations and games and move dealers fr...
# 12167  Answer telephones to provide information and r...
# 7411   Sing or dance during dramatic or comedic perfo...
# 11922  Resolve any problems with itineraries, service...
# 7664   Play musical instruments as soloists, or as me...
# 7645   Collaborate with other colleagues, such as cop...
#
#                                                   Actual  Predicted
# 12350  Performing for or Working Directly with the Pu...  Not PWDWP
# 12639  Performing for or Working Directly with the Pu...  Not PWDWP
# 7580   Performing for or Working Directly with the Pu...  Not PWDWP
# 11456  Performing for or Working Directly with the Pu...  Not PWDWP
# 11427  Performing for or Working Directly with the Pu...  Not PWDWP
# 12167  Performing for or Working Directly with the Pu...  Not PWDWP
# 7411   Performing for or Working Directly with the Pu...  Not PWDWP
# 11922  Performing for or Working Directly with the Pu...  Not PWDWP
# 7664   Performing for or Working Directly with the Pu...  Not PWDWP
# 7645   Performing for or Working Directly with the Pu...  Not PWDWP

# %%
#no stemming + no sampling
pwdwp_sample = df[df['GWA'] == 'Performing for or Working Directly with the Public']
nonpwdwp_df = df[df['GWA'] != 'Performing for or Working Directly with the Public']
nonpwdwp_df['GWA'] = ['Not PWDWP'] * nonpwdwp_df.shape[0]
equal_pwdwp_data = pd.concat([pwdwp_sample, nonpwdwp_df])
X_train, X_test, y_train, y_test = train_test_split(equal_pwdwp_data['Task'], 
                                                    equal_pwdwp_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

nonstem_logit_pipe.fit(X_train, y_train)

train_predicted = nonstem_logit_pipe.predict(X_train)
test_predicted = nonstem_logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results#[results['Actual'] != results['Predicted']].head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# Training Error:  0.006
# Precision:  [0.99357143 0.        ]
# Recall:  [1. 0.]
# F1-Score:  [0.99677535 0.        ]
# **********************************************************
# Test Error:  0.01
# Precision:  [0.98961938 0.        ]
# Recall:  [1. 0.]
# F1-Score:  [0.99478261 0.        ]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                                                     Task     Actual  Predicted
# 15585  Adjust, repair, or replace defective wiring an...  Not PWDWP  Not PWDWP
# 11826  Study production information, such as characte...  Not PWDWP  Not PWDWP
# 11331    Move and arrange furniture and turn mattresses.  Not PWDWP  Not PWDWP
# 5921          Supervise the work of survey interviewers.  Not PWDWP  Not PWDWP
# 3151   Identify need for initial or supplemental proj...  Not PWDWP  Not PWDWP
# 5853   Assemble, operate, or maintain field or labora...  Not PWDWP  Not PWDWP
# 7900   Organize recording sessions and prepare areas,...  Not PWDWP  Not PWDWP
# 10487  Testify in court cases involving fires, suspec...  Not PWDWP  Not PWDWP
# 3074   Design or prepare graphic representations of G...  Not PWDWP  Not PWDWP
# 18200  Note malfunctions of equipment, instruments, o...  Not PWDWP  Not PWDWP
# 18550  Stack cut items and load them on racks or conv...  Not PWDWP  Not PWDWP
# 2969   Establish functional or system standards to ad...  Not PWDWP  Not PWDWP
# 16810  Supervise assemblers and train employees on jo...  Not PWDWP  Not PWDWP
# 19587  Confer with conductors or traffic control cent...  Not PWDWP  Not PWDWP
# 2915   Develop testing programs that address areas su...  Not PWDWP  Not PWDWP
# 14949  Monitor construction activities to ensure that...  Not PWDWP  Not PWDWP
# 6106   Prepare students for later educational experie...  Not PWDWP  Not PWDWP
# 10687  Prepare and maintain required records, includi...  Not PWDWP  Not PWDWP
# 18203  Dispatch orders or instructions to personnel t...  Not PWDWP  Not PWDWP
# 6761   Perform administrative duties, such as assisti...  Not PWDWP  Not PWDWP
# 2265   Consult with managers to ensure that budget ad...  Not PWDWP  Not PWDWP
# 4077   Develop validation master plans, process flow ...  Not PWDWP  Not PWDWP
# 6096   Plan and promote career and employment-related...  Not PWDWP  Not PWDWP
# 8082   Replace missing teeth and associated oral stru...  Not PWDWP  Not PWDWP
# 17447  Develop templates and models for welding proje...  Not PWDWP  Not PWDWP
# 1314   Direct the development or implementation of co...  Not PWDWP  Not PWDWP
# 742    Evaluate construction methods and determine co...  Not PWDWP  Not PWDWP
# 8280   Evaluate patients to determine eligibility for...  Not PWDWP  Not PWDWP
# 12901  Perform routine data entry or other office sup...  Not PWDWP  Not PWDWP
# 3269   Apply mathematical theories and techniques to ...  Not PWDWP  Not PWDWP
# ...                                                  ...        ...        ...
# 9629   Collect samples, such as blood, urine, or sput...  Not PWDWP  Not PWDWP
# 15203  Bolt together pump and engine parts, and conne...  Not PWDWP  Not PWDWP
# 16951  Place products on carts or conveyors to transf...  Not PWDWP  Not PWDWP
# 12090  Hire, train, and evaluate personnel in sales o...  Not PWDWP  Not PWDWP
# 1560   Purchase the highest quality merchandise at th...  Not PWDWP  Not PWDWP
# 7610   Confer with clergy to select music for church ...  Not PWDWP  Not PWDWP
# 8706   Write treatment plans, case summaries, or prog...  Not PWDWP  Not PWDWP
# 726    Develop or implement environmental protection ...  Not PWDWP  Not PWDWP
# 14795  Fasten structural steel members to hoist cable...  Not PWDWP  Not PWDWP
# 10202  Perform clerical tasks, such as filing, compil...  Not PWDWP  Not PWDWP
# 3640   Operate computer-assisted engineering or desig...  Not PWDWP  Not PWDWP
# 2895   Install network software, including security o...  Not PWDWP  Not PWDWP
# 2600   Use the computer in the analysis and solution ...  Not PWDWP  Not PWDWP
# 5100   Monitor or operate specialized equipment such ...  Not PWDWP  Not PWDWP
# 9162   Examine patients with problems related to ocul...  Not PWDWP  Not PWDWP
# 4355   Supervise or conduct field surveys, inspection...  Not PWDWP  Not PWDWP
# 11666  Provide managers with budget recommendations a...  Not PWDWP  Not PWDWP
# 17770    Block or shape knitted garments after cleaning.  Not PWDWP  Not PWDWP
# 149    Coordinate with other marketing team members a...  Not PWDWP  Not PWDWP
# 5205   Determine methods of cutting and removing timb...  Not PWDWP  Not PWDWP
# 16971  Place products on conveyors or carts, and moni...  Not PWDWP  Not PWDWP
# 12179  Rent items, arrange for provision of services ...  Not PWDWP  Not PWDWP
# 3882   Conduct research that tests or analyzes the fe...  Not PWDWP  Not PWDWP
# 10590  Photograph crime or accident scenes for eviden...  Not PWDWP  Not PWDWP
# 18684  Create jewelry from materials such as gold, si...  Not PWDWP  Not PWDWP
# 5226   Investigate diseases or parasites to determine...  Not PWDWP  Not PWDWP
# 11797  Comb, brush, and spray hair or wigs to set style.  Not PWDWP  Not PWDWP
# 4402   Design scale or full-size blueprints of specia...  Not PWDWP  Not PWDWP
# 13368  Maintain files, such as maintenance records, b...  Not PWDWP  Not PWDWP
# 6158   Refer patients, clients, or family members to ...  Not PWDWP  Not PWDWP
#
# [2023 rows x 3 columns]

# %% [markdown]
# So far the results of the sampling methods are promising, although the accuracy of the model gets worse as the size of the target class gets smaller. Lastly, lets try the sampling method on the smallest target class.
#
# ---
#
# ### Target Class: Coaching and Developing Others

# %%
#baseline preprocessing + sampling
cado_sample = df[df['GWA'] == 'Coaching and Developing Others'].sample(40)
noncado_df = df[df['GWA'] != 'Coaching and Developing Others'].sample(40)
noncado_df['GWA'] = ['Not Coaching and Developing Others'] * 40
equal_cado_data = pd.concat([cado_sample, noncado_df])
X_train, X_test, y_train, y_test = train_test_split(equal_cado_data['Task'], 
                                                    equal_cado_data['GWA'], 
                                                    test_size = 0.10,
                                                    shuffle = True)

logit_pipe.fit(X_train, y_train)

train_predicted = logit_pipe.predict(X_train)
test_predicted = logit_pipe.predict(X_test)

train_p, train_r, train_f1, train_s = precision_recall_fscore_support(y_train, train_predicted, labels = y_train.unique())
print('Training Error: ', round(sum(train_predicted != y_train)/len(y_train), 3))
print('Precision: ', train_p)
print('Recall: ', train_r)
print('F1-Score: ', train_f1)
print('**********************************************************')
print('Test Error: ', round(sum(test_predicted != y_test)/len(y_test), 3))
test_p, test_r, test_f1, test_s = precision_recall_fscore_support(y_test, test_predicted, labels = y_train.unique())
print('Precision: ', test_p)
print('Recall: ', test_r)
print('F1-Score: ', test_f1)

results = pd.DataFrame({'Task': X_test, 'Actual': y_test, 'Predicted': test_predicted})
results[results['Actual'] != results['Predicted']].head(10)
# Out:
# Training Error:  0.0
# Precision:  [1. 1.]
# Recall:  [1. 1.]
# F1-Score:  [1. 1.]
# **********************************************************
# Test Error:  0.0
# Precision:  [1. 1.]
# Recall:  [1. 1.]
# F1-Score:  [1. 1.]
# Empty DataFrame
# Columns: [Task, Actual, Predicted]
# Index: []

# %% [markdown]
# The size of this class was so small it is difficult to put much confidence in our results for this experiment, although the model did supposedly perform very well. In general, the sampling method seems to be quite effective so we'll use this procedure in our final model.
